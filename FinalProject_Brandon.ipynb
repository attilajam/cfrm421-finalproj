# %% [markdown]
# # Predicting closing price movements of NASDAQ stocks
# Code and text done by Attila Jamilov, Cooper Reynolds, some code by Yueying Du, Brandon Leong, Josephine Welin.
# ## Introduction
# In the last minutes of the market being open, many stocks see heightened volatility as well as big price fluctuation. NASDAQ stock exchange uses the NASDAQ Closing Cross auction to determine the official closing prices for various assets on their exchange. We want to evaluate the performance of multiple models that we learned in class and not, on predicting this closing price movement using the dataset provided in the [Kaggle](https://www.kaggle.com/competitions/optiver-trading-at-the-close/overview), and see what models performs best, and what features we can engineer to improve on the performance of the models.
#
# ### Project Goal
# We evaluate how well different machine learning algorithms can predict stock price movement near the market close. Our specific target is the change in the *market clearing price* during the NASDAQ Closing Cross.
#
# ### Data Overview
# Each row represents auction-related market activity for a given stock on a given day. For our features, we will try using only the features provided in the dataset, then creating our own original features, trying features that the Kaggle competitors had success with, and finally a compilation of all features. Then, we will select only the most helpful features, and then test our best model on the test data set through the Kaggle.
#
# ### Models and Algorithms
# For our models, we will begin with Linear Regression (Josephine), Random Forest (Brandon), LightGBM and CNN (Yueying), XGBoost (Cooper), and finally we will look into Catboost (Attila), a model developed by Yandex which the winner of the Kaggle used for his approach to this Kaggle. We compare all of these models using mean average error.
#
# ## Dataset explanation
#
# ## Data Processing
# First, we need to import the data:

# %%
# Data processing done by Attila and Cooper
import pandas as pd

def process_data(df: pd.DataFrame):
    df.dropna(subset=["target"], inplace=True)
    X = df.drop(["target"], axis=1)
    y = df["target"]
    return X, y

# %% [markdown]
# We also define several processing functions.
#
# The function process_data_drop_null_target removes all rows with missing target values.
#
# The function process_data_drop_prices removes rows with missing near_price or far_price, because some models (linear regression) can't handle null features.

# %%
def process_data_drop_null_target(df: pd.DataFrame):
    df_processed = df.dropna(subset=["target"]).copy()
    X = df_processed.drop(["target"], axis=1)
    y = df_processed["target"]
    return X, y

def process_data_drop_prices(df: pd.DataFrame):
    df_processed = df.dropna(subset=["near_price", "far_price"]).copy()
    X = df_processed.drop(["target"], axis=1)
    y = df_processed["target"]
    return X, y

# %% [markdown]
# We create a general training function to handle training multiple models with the same dataset, as well as specialized cases for LightGBM due to early stopping and evaluation.

# %%
def train_model(model_class, X_train, y_train, X_val, y_val, params=None):
    if params:
        model = model_class(**params)
    else:
        model = model_class()

    if isinstance(model, LGBMRegressor):
        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            eval_metric='mae',
            callbacks=[
                early_stopping(stopping_rounds=150, verbose=True),
                log_evaluation(period=150)
            ]
        )
    else:
        model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    mae = mean_absolute_error(y_val, y_pred)
    return mae, model

df = pd.read_csv("./train.csv", index_col="row_id") 

df = df.sample(frac=0.1, random_state=42)

# %%
X, y = process_data_drop_null_target(df.copy())

# %% [markdown]
# We 'remove' the identifying feature "row_id", but we set it as the `index_col`, which is necessary for submitting to the Kaggle but will not be used as a feature when training the models.
#
# Next, we need to split the data into a training and validating subsets:

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# `train_test_split` shuffles the data on it's own, therefore there is nothing we need to do on that part. We are done with our initial data processing, but certain models cannot handle NaN values, so individual work will need to be done to get them to work. Now we can move on to Naive model training with the most basic features.

# %% [markdown]
# ## Naive feature selection
#
# Before doing any feature selection, we will first evaluate the baseline performance of our models on only the original given features from the dataset. This gives us a benchmark to assess our engineered features.

# %%
# Linear Regression
# Original code by Josephine, appended and corrected to work with data to Notebook by Attila, Cooper
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from lightgbm import LGBMRegressor, early_stopping, log_evaluation


X_lr, y_lr = process_data_drop_prices(df.copy())
X_train_lr, X_val_lr, y_train_lr, y_val_lr = train_test_split(X_lr, y_lr, test_size=0.33, random_state=42)
mae_lr, _ = train_model(LinearRegression, X_train_lr, y_train_lr, X_val_lr, y_val_lr)

# %% [markdown]
# Random forest is an ensemble learning method that utilizes decision trees to output average predictions. While easy to tune, training on the full data set was computationally intensive and inefficient due to it's size. Since Random Forest was a core part of our class' material, we included it by training it on a smaller (5%) random sample of the dataset to reduce training time even though it isn't a good fit for what we are trying to achieve.

# %%
# Random Forest
# Original code by Brandon, appended and corrected to work with data to Notebook by Attila, Cooper
from sklearn.ensemble import RandomForestRegressor

df_rf = df.sample(frac=0.05).copy()
X_rf, y_rf = process_data_drop_null_target(df_rf)
X_train_rf, X_val_rf, y_train_rf, y_val_rf = train_test_split(X_rf, y_rf, test_size=0.33, random_state=42)
rf_params = {"n_estimators": 100, "random_state": 42, "n_jobs": -1}
mae_rf, _ = train_model(RandomForestRegressor, X_train_rf, y_train_rf, X_val_rf, y_val_rf, params=rf_params)

# %% [markdown]
# LightGBM (Light Gradient Boosting Machine) is a high-performance gradient boosting framework that is well-suited for large-scale datasets and tabular data with many features. It is particularly efficient for training on millions of observations, which made it a practical choice for our dataset of over 5 million instances.

# %%
# LightGBM
# Original code by Yueying, appended to notebook by Attila, Cooper

lgbm_params = {
    'objective': 'regression',
    'metric': 'mae',
    'boosting_type': 'gbdt',
    'learning_rate': 0.03,
    'num_leaves': 31,
    'n_estimators': 2000,
    'min_child_samples': 50,
    'lambda_l1': 0.5,
    'lambda_l2': 0.5,
    'device': 'CPU',
    'random_state': 42,
    'n_jobs': -1
}
mae_lgbm, _ = train_model(LGBMRegressor, X_train, y_train, X_val, y_val, params=lgbm_params)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004710 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3316
# [LightGBM] [Info] Number of data points in the train set: 350939, number of used features: 15
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Info] Start training from score -0.026625
# Training until validation scores don't improve for 150 rounds
# [150]	valid_0's l1: 6.32681
# [300]	valid_0's l1: 6.31888
# [450]	valid_0's l1: 6.3149
# [600]	valid_0's l1: 6.31322
# [750]	valid_0's l1: 6.31105
# [900]	valid_0's l1: 6.30933
# [1050]	valid_0's l1: 6.30834
# [1200]	valid_0's l1: 6.30757
# [1350]	valid_0's l1: 6.30704
# [1500]	valid_0's l1: 6.30636
# [1650]	valid_0's l1: 6.30576
# [1800]	valid_0's l1: 6.30483
# [1950]	valid_0's l1: 6.30448
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's l1: 6.30436
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5

# %% [markdown]
# This code is for training an XGBoost regression model, evaluating it with MAE, and inspecting feature importances. It accepts the training and validation features and target values, along with a list of feature names to use for training. The function configures the model with predefined hyperparameters. These include a squared error objective, mean absolute error (MAE) as the evaluation, a learning rate of 0.05, and a maximum tree depth of 6. After training, it makes predictions and calculates the MAE to determine performance.

# %%
import xgboost

xgb_params = {
    'objective': 'reg:absoluteerror',
    'eval_metric': 'mae',
    'device': "cuda",
    'random_state': 42
}
mae_xgb, _ = train_model(xgboost.XGBRegressor, X_train, y_train, X_val, y_val, params=xgb_params)
# Out:
# /Users/bbwalrus/cfrm421-finalproj-1/.venv/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [02:04:53] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:203: XGBoost is not compiled with CUDA support.
#   bst.update(dtrain, iteration=i, fobj=obj)

# %% [markdown]
# Catboost is the model that was used to win first place in the Kaggle. Catboost itself is an algorithm with a novel gradient-boosting scheme on decision trees. It is developed by Yandex, and it has many benefits, such as providing great quality with the default parameters, saving time from parameter tuning, and it supports categorical features, instead of having to pre-process data to numerical values.

# %%
from catboost import CatBoostRegressor

cb_params = {"loss_function": "MAE", "random_state": 42, "verbose": 1, "task_type": "CPU", "thread_count": -1, "cat_features": ['stock_id', 'imbalance_buy_sell_flag'] }
mae_cb, _ = train_model(CatBoostRegressor, X_train, y_train, X_val, y_val, params=cb_params)
# Out:
# 0:	learn: 6.4050494	total: 59ms	remaining: 59s
# 1:	learn: 6.4021959	total: 117ms	remaining: 58.5s
# 2:	learn: 6.3997248	total: 175ms	remaining: 58.3s
# 3:	learn: 6.3973006	total: 230ms	remaining: 57.4s
# 4:	learn: 6.3948483	total: 288ms	remaining: 57.2s
# 5:	learn: 6.3924930	total: 342ms	remaining: 56.6s
# 6:	learn: 6.3905573	total: 392ms	remaining: 55.5s
# 7:	learn: 6.3886754	total: 458ms	remaining: 56.8s
# 8:	learn: 6.3866726	total: 517ms	remaining: 56.9s
# 9:	learn: 6.3848106	total: 583ms	remaining: 57.7s
# 10:	learn: 6.3830461	total: 645ms	remaining: 58s
# 11:	learn: 6.3813733	total: 706ms	remaining: 58.1s
# 12:	learn: 6.3797903	total: 766ms	remaining: 58.1s
# 13:	learn: 6.3783677	total: 818ms	remaining: 57.6s
# 14:	learn: 6.3769530	total: 875ms	remaining: 57.5s
# 15:	learn: 6.3756847	total: 931ms	remaining: 57.2s
# 16:	learn: 6.3745334	total: 989ms	remaining: 57.2s
# 17:	learn: 6.3733299	total: 1.05s	remaining: 57.5s
# 18:	learn: 6.3721532	total: 1.11s	remaining: 57.5s
# 19:	learn: 6.3711233	total: 1.17s	remaining: 57.3s
# 20:	learn: 6.3699772	total: 1.23s	remaining: 57.4s
# 21:	learn: 6.3689713	total: 1.29s	remaining: 57.3s
# 22:	learn: 6.3679571	total: 1.35s	remaining: 57.6s
# 23:	learn: 6.3670666	total: 1.42s	remaining: 57.8s
# 24:	learn: 6.3662227	total: 1.49s	remaining: 58s
# 25:	learn: 6.3652916	total: 1.55s	remaining: 58s
# 26:	learn: 6.3645126	total: 1.62s	remaining: 58.4s
# 27:	learn: 6.3637536	total: 1.68s	remaining: 58.3s
# 28:	learn: 6.3631484	total: 1.73s	remaining: 58.1s
# 29:	learn: 6.3624403	total: 1.79s	remaining: 58s
# 30:	learn: 6.3618500	total: 1.85s	remaining: 57.8s
# 31:	learn: 6.3612049	total: 1.91s	remaining: 57.8s
# 32:	learn: 6.3605488	total: 1.97s	remaining: 57.7s
# 33:	learn: 6.3600222	total: 2.02s	remaining: 57.4s
# 34:	learn: 6.3594469	total: 2.08s	remaining: 57.3s
# 35:	learn: 6.3588540	total: 2.14s	remaining: 57.2s
# 36:	learn: 6.3582249	total: 2.19s	remaining: 57s
# 37:	learn: 6.3577331	total: 2.25s	remaining: 57s
# 38:	learn: 6.3572349	total: 2.3s	remaining: 56.8s
# 39:	learn: 6.3566625	total: 2.36s	remaining: 56.7s
# 40:	learn: 6.3562103	total: 2.42s	remaining: 56.7s
# 41:	learn: 6.3558029	total: 2.49s	remaining: 56.8s
# 42:	learn: 6.3553315	total: 2.54s	remaining: 56.6s
# 43:	learn: 6.3547161	total: 2.61s	remaining: 56.7s
# 44:	learn: 6.3543799	total: 2.67s	remaining: 56.7s
# 45:	learn: 6.3540233	total: 2.73s	remaining: 56.7s
# 46:	learn: 6.3534929	total: 2.79s	remaining: 56.6s
# 47:	learn: 6.3531053	total: 2.84s	remaining: 56.4s
# 48:	learn: 6.3527264	total: 2.9s	remaining: 56.3s
# 49:	learn: 6.3523937	total: 2.96s	remaining: 56.2s
# 50:	learn: 6.3519226	total: 3.01s	remaining: 56.1s
# 51:	learn: 6.3514408	total: 3.07s	remaining: 56s
# 52:	learn: 6.3511629	total: 3.13s	remaining: 56s
# 53:	learn: 6.3508378	total: 3.19s	remaining: 56s
# 54:	learn: 6.3505789	total: 3.25s	remaining: 55.9s
# 55:	learn: 6.3502291	total: 3.31s	remaining: 55.8s
# 56:	learn: 6.3497432	total: 3.37s	remaining: 55.7s
# 57:	learn: 6.3494682	total: 3.43s	remaining: 55.7s
# 58:	learn: 6.3491386	total: 3.49s	remaining: 55.7s
# 59:	learn: 6.3488778	total: 3.55s	remaining: 55.6s
# 60:	learn: 6.3483776	total: 3.61s	remaining: 55.5s
# 61:	learn: 6.3481110	total: 3.67s	remaining: 55.5s
# 62:	learn: 6.3478526	total: 3.73s	remaining: 55.4s
# 63:	learn: 6.3476186	total: 3.77s	remaining: 55.2s
# 64:	learn: 6.3472437	total: 3.83s	remaining: 55.1s
# 65:	learn: 6.3470322	total: 3.88s	remaining: 54.9s
# 66:	learn: 6.3466367	total: 3.94s	remaining: 54.9s
# 67:	learn: 6.3464663	total: 4s	remaining: 54.9s
# 68:	learn: 6.3462173	total: 4.07s	remaining: 54.9s
# 69:	learn: 6.3460531	total: 4.12s	remaining: 54.8s
# 70:	learn: 6.3458646	total: 4.18s	remaining: 54.7s
# 71:	learn: 6.3455489	total: 4.24s	remaining: 54.7s
# 72:	learn: 6.3453719	total: 4.3s	remaining: 54.6s
# 73:	learn: 6.3450264	total: 4.36s	remaining: 54.6s
# 74:	learn: 6.3447396	total: 4.42s	remaining: 54.5s
# 75:	learn: 6.3445709	total: 4.47s	remaining: 54.4s
# 76:	learn: 6.3443918	total: 4.54s	remaining: 54.4s
# 77:	learn: 6.3442114	total: 4.59s	remaining: 54.3s
# 78:	learn: 6.3439269	total: 4.65s	remaining: 54.3s
# 79:	learn: 6.3437265	total: 4.72s	remaining: 54.2s
# 80:	learn: 6.3434763	total: 4.78s	remaining: 54.2s
# 81:	learn: 6.3433033	total: 4.83s	remaining: 54.1s
# 82:	learn: 6.3429751	total: 4.9s	remaining: 54.1s
# 83:	learn: 6.3427228	total: 4.96s	remaining: 54.1s
# 84:	learn: 6.3424314	total: 5.02s	remaining: 54s
# 85:	learn: 6.3421721	total: 5.07s	remaining: 53.9s
# 86:	learn: 6.3419297	total: 5.15s	remaining: 54s
# 87:	learn: 6.3416320	total: 5.21s	remaining: 54s
# 88:	learn: 6.3415127	total: 5.28s	remaining: 54s
# 89:	learn: 6.3413886	total: 5.33s	remaining: 53.9s
# 90:	learn: 6.3410546	total: 5.39s	remaining: 53.9s
# 91:	learn: 6.3407205	total: 5.45s	remaining: 53.8s
# 92:	learn: 6.3405766	total: 5.51s	remaining: 53.8s
# 93:	learn: 6.3402771	total: 5.57s	remaining: 53.7s
# 94:	learn: 6.3401500	total: 5.63s	remaining: 53.6s
# 95:	learn: 6.3398515	total: 5.68s	remaining: 53.5s
# 96:	learn: 6.3395592	total: 5.74s	remaining: 53.5s
# 97:	learn: 6.3392542	total: 5.8s	remaining: 53.4s
# 98:	learn: 6.3391027	total: 5.86s	remaining: 53.4s
# 99:	learn: 6.3388666	total: 5.92s	remaining: 53.3s
# 100:	learn: 6.3386025	total: 5.98s	remaining: 53.2s
# 101:	learn: 6.3383994	total: 6.04s	remaining: 53.2s
# 102:	learn: 6.3382734	total: 6.11s	remaining: 53.2s
# 103:	learn: 6.3380723	total: 6.16s	remaining: 53.1s
# 104:	learn: 6.3378465	total: 6.23s	remaining: 53.1s
# 105:	learn: 6.3376239	total: 6.3s	remaining: 53.2s
# 106:	learn: 6.3374123	total: 6.36s	remaining: 53.1s
# 107:	learn: 6.3372698	total: 6.42s	remaining: 53s
# 108:	learn: 6.3370476	total: 6.48s	remaining: 53s
# 109:	learn: 6.3370096	total: 6.53s	remaining: 52.8s
# 110:	learn: 6.3367948	total: 6.58s	remaining: 52.7s
# 111:	learn: 6.3366119	total: 6.64s	remaining: 52.7s
# 112:	learn: 6.3363618	total: 6.7s	remaining: 52.6s
# 113:	learn: 6.3360383	total: 6.76s	remaining: 52.6s
# 114:	learn: 6.3358491	total: 6.82s	remaining: 52.5s
# 115:	learn: 6.3355341	total: 6.88s	remaining: 52.5s
# 116:	learn: 6.3353847	total: 6.95s	remaining: 52.4s
# 117:	learn: 6.3351599	total: 7s	remaining: 52.3s
# 118:	learn: 6.3349249	total: 7.06s	remaining: 52.3s
# 119:	learn: 6.3348993	total: 7.1s	remaining: 52.1s
# 120:	learn: 6.3346901	total: 7.16s	remaining: 52s
# 121:	learn: 6.3346139	total: 7.22s	remaining: 52s
# 122:	learn: 6.3343515	total: 7.29s	remaining: 52s
# 123:	learn: 6.3340942	total: 7.35s	remaining: 51.9s
# 124:	learn: 6.3339878	total: 7.4s	remaining: 51.8s
# 125:	learn: 6.3339240	total: 7.46s	remaining: 51.7s
# 126:	learn: 6.3337597	total: 7.51s	remaining: 51.7s
# 127:	learn: 6.3335076	total: 7.57s	remaining: 51.5s
# 128:	learn: 6.3332939	total: 7.62s	remaining: 51.5s
# 129:	learn: 6.3331159	total: 7.68s	remaining: 51.4s
# 130:	learn: 6.3329183	total: 7.74s	remaining: 51.4s
# 131:	learn: 6.3327216	total: 7.8s	remaining: 51.3s
# 132:	learn: 6.3324621	total: 7.87s	remaining: 51.3s
# 133:	learn: 6.3322350	total: 7.92s	remaining: 51.2s
# 134:	learn: 6.3319456	total: 7.98s	remaining: 51.1s
# 135:	learn: 6.3317495	total: 8.04s	remaining: 51.1s
# 136:	learn: 6.3316602	total: 8.11s	remaining: 51.1s
# 137:	learn: 6.3314627	total: 8.18s	remaining: 51.1s
# 138:	learn: 6.3312995	total: 8.23s	remaining: 51s
# 139:	learn: 6.3311900	total: 8.29s	remaining: 50.9s
# 140:	learn: 6.3310345	total: 8.35s	remaining: 50.9s
# 141:	learn: 6.3308896	total: 8.41s	remaining: 50.8s
# 142:	learn: 6.3307207	total: 8.48s	remaining: 50.8s
# 143:	learn: 6.3305442	total: 8.54s	remaining: 50.8s
# 144:	learn: 6.3303765	total: 8.61s	remaining: 50.8s
# 145:	learn: 6.3301673	total: 8.68s	remaining: 50.8s
# 146:	learn: 6.3299901	total: 8.74s	remaining: 50.7s
# 147:	learn: 6.3298499	total: 8.81s	remaining: 50.7s
# 148:	learn: 6.3296828	total: 8.87s	remaining: 50.7s
# 149:	learn: 6.3294773	total: 8.93s	remaining: 50.6s
# 150:	learn: 6.3293691	total: 8.98s	remaining: 50.5s
# 151:	learn: 6.3292093	total: 9.05s	remaining: 50.5s
# 152:	learn: 6.3291483	total: 9.11s	remaining: 50.4s
# 153:	learn: 6.3289692	total: 9.17s	remaining: 50.4s
# 154:	learn: 6.3288648	total: 9.22s	remaining: 50.3s
# 155:	learn: 6.3287246	total: 9.29s	remaining: 50.2s
# 156:	learn: 6.3285502	total: 9.35s	remaining: 50.2s
# 157:	learn: 6.3283092	total: 9.41s	remaining: 50.1s
# 158:	learn: 6.3281505	total: 9.47s	remaining: 50.1s
# 159:	learn: 6.3279021	total: 9.53s	remaining: 50.1s
# 160:	learn: 6.3276697	total: 9.59s	remaining: 50s
# 161:	learn: 6.3275689	total: 9.64s	remaining: 49.9s
# 162:	learn: 6.3273621	total: 9.71s	remaining: 49.9s
# 163:	learn: 6.3271787	total: 9.77s	remaining: 49.8s
# 164:	learn: 6.3270290	total: 9.83s	remaining: 49.7s
# 165:	learn: 6.3268692	total: 9.88s	remaining: 49.7s
# 166:	learn: 6.3268237	total: 9.94s	remaining: 49.6s
# 167:	learn: 6.3267775	total: 9.99s	remaining: 49.5s
# 168:	learn: 6.3266259	total: 10s	remaining: 49.4s
# 169:	learn: 6.3264744	total: 10.1s	remaining: 49.3s
# 170:	learn: 6.3263008	total: 10.2s	remaining: 49.3s
# 171:	learn: 6.3261929	total: 10.2s	remaining: 49.3s
# 172:	learn: 6.3260613	total: 10.3s	remaining: 49.2s
# 173:	learn: 6.3258860	total: 10.4s	remaining: 49.1s
# 174:	learn: 6.3258588	total: 10.4s	remaining: 49.1s
# 175:	learn: 6.3257092	total: 10.5s	remaining: 49s
# 176:	learn: 6.3256258	total: 10.5s	remaining: 49s
# 177:	learn: 6.3255051	total: 10.6s	remaining: 48.9s
# 178:	learn: 6.3253981	total: 10.6s	remaining: 48.8s
# 179:	learn: 6.3252435	total: 10.7s	remaining: 48.8s
# 180:	learn: 6.3252089	total: 10.8s	remaining: 48.8s
# 181:	learn: 6.3250523	total: 10.8s	remaining: 48.7s
# 182:	learn: 6.3248787	total: 10.9s	remaining: 48.7s
# 183:	learn: 6.3247483	total: 11s	remaining: 48.6s
# 184:	learn: 6.3246489	total: 11s	remaining: 48.5s
# 185:	learn: 6.3245427	total: 11.1s	remaining: 48.5s
# 186:	learn: 6.3243562	total: 11.1s	remaining: 48.4s
# 187:	learn: 6.3242359	total: 11.2s	remaining: 48.4s
# 188:	learn: 6.3240889	total: 11.3s	remaining: 48.3s
# 189:	learn: 6.3239754	total: 11.3s	remaining: 48.2s
# 190:	learn: 6.3239100	total: 11.4s	remaining: 48.1s
# 191:	learn: 6.3237006	total: 11.4s	remaining: 48s
# 192:	learn: 6.3234507	total: 11.5s	remaining: 48s
# 193:	learn: 6.3234126	total: 11.5s	remaining: 47.9s
# 194:	learn: 6.3234094	total: 11.6s	remaining: 47.7s
# 195:	learn: 6.3233472	total: 11.6s	remaining: 47.7s
# 196:	learn: 6.3232376	total: 11.7s	remaining: 47.6s
# 197:	learn: 6.3231497	total: 11.7s	remaining: 47.5s
# 198:	learn: 6.3230907	total: 11.8s	remaining: 47.5s
# 199:	learn: 6.3229926	total: 11.8s	remaining: 47.4s
# 200:	learn: 6.3229162	total: 11.9s	remaining: 47.3s
# 201:	learn: 6.3228869	total: 11.9s	remaining: 47.2s
# 202:	learn: 6.3228569	total: 12s	remaining: 47.1s
# 203:	learn: 6.3227461	total: 12.1s	remaining: 47.1s
# 204:	learn: 6.3227166	total: 12.1s	remaining: 47s
# 205:	learn: 6.3226243	total: 12.2s	remaining: 47s
# 206:	learn: 6.3225603	total: 12.2s	remaining: 46.9s
# 207:	learn: 6.3224943	total: 12.3s	remaining: 46.8s
# 208:	learn: 6.3223703	total: 12.4s	remaining: 46.7s
# 209:	learn: 6.3222527	total: 12.4s	remaining: 46.7s
# 210:	learn: 6.3221430	total: 12.5s	remaining: 46.6s
# 211:	learn: 6.3219694	total: 12.5s	remaining: 46.6s
# 212:	learn: 6.3218837	total: 12.6s	remaining: 46.5s
# 213:	learn: 6.3218059	total: 12.7s	remaining: 46.6s
# 214:	learn: 6.3216119	total: 12.8s	remaining: 46.6s
# 215:	learn: 6.3214738	total: 12.8s	remaining: 46.5s
# 216:	learn: 6.3213993	total: 12.9s	remaining: 46.4s
# 217:	learn: 6.3212967	total: 12.9s	remaining: 46.4s
# 218:	learn: 6.3211503	total: 13s	remaining: 46.3s
# 219:	learn: 6.3210260	total: 13.1s	remaining: 46.3s
# 220:	learn: 6.3209409	total: 13.1s	remaining: 46.2s
# 221:	learn: 6.3208821	total: 13.2s	remaining: 46.1s
# 222:	learn: 6.3208139	total: 13.2s	remaining: 46s
# 223:	learn: 6.3207830	total: 13.3s	remaining: 45.9s
# 224:	learn: 6.3206265	total: 13.3s	remaining: 45.9s
# 225:	learn: 6.3205645	total: 13.4s	remaining: 45.8s
# 226:	learn: 6.3204612	total: 13.4s	remaining: 45.8s
# 227:	learn: 6.3203293	total: 13.5s	remaining: 45.7s
# 228:	learn: 6.3203214	total: 13.6s	remaining: 45.6s
# 229:	learn: 6.3202121	total: 13.6s	remaining: 45.6s
# 230:	learn: 6.3200885	total: 13.7s	remaining: 45.5s
# 231:	learn: 6.3199638	total: 13.7s	remaining: 45.5s
# 232:	learn: 6.3197889	total: 13.8s	remaining: 45.4s
# 233:	learn: 6.3196842	total: 13.8s	remaining: 45.3s
# 234:	learn: 6.3196571	total: 13.9s	remaining: 45.2s
# 235:	learn: 6.3195407	total: 14s	remaining: 45.2s
# 236:	learn: 6.3193521	total: 14s	remaining: 45.1s
# 237:	learn: 6.3192067	total: 14.1s	remaining: 45.1s
# 238:	learn: 6.3191270	total: 14.1s	remaining: 45s
# 239:	learn: 6.3191011	total: 14.2s	remaining: 45s
# 240:	learn: 6.3190050	total: 14.3s	remaining: 44.9s
# 241:	learn: 6.3189558	total: 14.3s	remaining: 44.9s
# 242:	learn: 6.3188653	total: 14.4s	remaining: 44.8s
# 243:	learn: 6.3187527	total: 14.4s	remaining: 44.7s
# 244:	learn: 6.3186659	total: 14.5s	remaining: 44.7s
# 245:	learn: 6.3185599	total: 14.6s	remaining: 44.6s
# 246:	learn: 6.3184150	total: 14.6s	remaining: 44.5s
# 247:	learn: 6.3183060	total: 14.7s	remaining: 44.5s
# 248:	learn: 6.3182282	total: 14.7s	remaining: 44.4s
# 249:	learn: 6.3180804	total: 14.8s	remaining: 44.3s
# 250:	learn: 6.3179022	total: 14.8s	remaining: 44.2s
# 251:	learn: 6.3178411	total: 14.9s	remaining: 44.2s
# 252:	learn: 6.3177212	total: 15s	remaining: 44.2s
# 253:	learn: 6.3176236	total: 15s	remaining: 44.1s
# 254:	learn: 6.3174924	total: 15.1s	remaining: 44.1s
# 255:	learn: 6.3174143	total: 15.1s	remaining: 44s
# 256:	learn: 6.3173749	total: 15.2s	remaining: 43.9s
# 257:	learn: 6.3173191	total: 15.3s	remaining: 43.9s
# 258:	learn: 6.3171721	total: 15.3s	remaining: 43.8s
# 259:	learn: 6.3171440	total: 15.4s	remaining: 43.7s
# 260:	learn: 6.3170585	total: 15.4s	remaining: 43.7s
# 261:	learn: 6.3169946	total: 15.5s	remaining: 43.6s
# 262:	learn: 6.3168188	total: 15.5s	remaining: 43.6s
# 263:	learn: 6.3166356	total: 15.6s	remaining: 43.5s
# 264:	learn: 6.3164884	total: 15.7s	remaining: 43.5s
# 265:	learn: 6.3163729	total: 15.7s	remaining: 43.4s
# 266:	learn: 6.3162330	total: 15.8s	remaining: 43.4s
# 267:	learn: 6.3161485	total: 15.9s	remaining: 43.4s
# 268:	learn: 6.3159929	total: 15.9s	remaining: 43.3s
# 269:	learn: 6.3158652	total: 16s	remaining: 43.3s
# 270:	learn: 6.3157448	total: 16.1s	remaining: 43.2s
# 271:	learn: 6.3156961	total: 16.1s	remaining: 43.2s
# 272:	learn: 6.3155291	total: 16.2s	remaining: 43.1s
# 273:	learn: 6.3153928	total: 16.2s	remaining: 43s
# 274:	learn: 6.3152986	total: 16.3s	remaining: 43s
# 275:	learn: 6.3151999	total: 16.4s	remaining: 42.9s
# 276:	learn: 6.3150168	total: 16.4s	remaining: 42.9s
# 277:	learn: 6.3148570	total: 16.5s	remaining: 42.8s
# 278:	learn: 6.3147538	total: 16.6s	remaining: 42.8s
# 279:	learn: 6.3147501	total: 16.6s	remaining: 42.7s
# 280:	learn: 6.3146482	total: 16.7s	remaining: 42.6s
# 281:	learn: 6.3145819	total: 16.7s	remaining: 42.6s
# 282:	learn: 6.3144525	total: 16.8s	remaining: 42.5s
# 283:	learn: 6.3143419	total: 16.8s	remaining: 42.4s
# 284:	learn: 6.3142839	total: 16.9s	remaining: 42.4s
# 285:	learn: 6.3142151	total: 16.9s	remaining: 42.3s
# 286:	learn: 6.3141515	total: 17s	remaining: 42.2s
# 287:	learn: 6.3140419	total: 17.1s	remaining: 42.2s
# 288:	learn: 6.3140003	total: 17.1s	remaining: 42.1s
# 289:	learn: 6.3139195	total: 17.2s	remaining: 42.1s
# 290:	learn: 6.3137484	total: 17.2s	remaining: 42s
# 291:	learn: 6.3136459	total: 17.3s	remaining: 42s
# 292:	learn: 6.3135688	total: 17.4s	remaining: 41.9s
# 293:	learn: 6.3134011	total: 17.4s	remaining: 41.9s
# 294:	learn: 6.3132892	total: 17.5s	remaining: 41.8s
# 295:	learn: 6.3131943	total: 17.6s	remaining: 41.8s
# 296:	learn: 6.3130691	total: 17.6s	remaining: 41.7s
# 297:	learn: 6.3129875	total: 17.7s	remaining: 41.6s
# 298:	learn: 6.3129506	total: 17.7s	remaining: 41.6s
# 299:	learn: 6.3128609	total: 17.8s	remaining: 41.5s
# 300:	learn: 6.3127999	total: 17.8s	remaining: 41.4s
# 301:	learn: 6.3126690	total: 17.9s	remaining: 41.4s
# 302:	learn: 6.3125890	total: 18s	remaining: 41.3s
# 303:	learn: 6.3125376	total: 18s	remaining: 41.3s
# 304:	learn: 6.3124290	total: 18.1s	remaining: 41.2s
# 305:	learn: 6.3122800	total: 18.1s	remaining: 41.1s
# 306:	learn: 6.3122088	total: 18.2s	remaining: 41.1s
# 307:	learn: 6.3120107	total: 18.3s	remaining: 41s
# 308:	learn: 6.3118588	total: 18.3s	remaining: 40.9s
# 309:	learn: 6.3117025	total: 18.4s	remaining: 40.9s
# 310:	learn: 6.3117025	total: 18.4s	remaining: 40.7s
# 311:	learn: 6.3116721	total: 18.4s	remaining: 40.7s
# 312:	learn: 6.3116319	total: 18.5s	remaining: 40.6s
# 313:	learn: 6.3114914	total: 18.6s	remaining: 40.5s
# 314:	learn: 6.3113885	total: 18.6s	remaining: 40.5s
# 315:	learn: 6.3113302	total: 18.7s	remaining: 40.4s
# 316:	learn: 6.3111728	total: 18.7s	remaining: 40.4s
# 317:	learn: 6.3111453	total: 18.8s	remaining: 40.3s
# 318:	learn: 6.3111173	total: 18.9s	remaining: 40.3s
# 319:	learn: 6.3110286	total: 18.9s	remaining: 40.2s
# 320:	learn: 6.3109162	total: 19s	remaining: 40.1s
# 321:	learn: 6.3108566	total: 19s	remaining: 40s
# 322:	learn: 6.3107350	total: 19.1s	remaining: 40s
# 323:	learn: 6.3106865	total: 19.1s	remaining: 39.9s
# 324:	learn: 6.3105659	total: 19.2s	remaining: 39.9s
# 325:	learn: 6.3104066	total: 19.3s	remaining: 39.8s
# 326:	learn: 6.3102855	total: 19.3s	remaining: 39.8s
# 327:	learn: 6.3102380	total: 19.4s	remaining: 39.7s
# 328:	learn: 6.3102023	total: 19.4s	remaining: 39.6s
# 329:	learn: 6.3101163	total: 19.5s	remaining: 39.6s
# 330:	learn: 6.3100496	total: 19.5s	remaining: 39.5s
# 331:	learn: 6.3099648	total: 19.6s	remaining: 39.5s
# 332:	learn: 6.3097990	total: 19.7s	remaining: 39.4s
# 333:	learn: 6.3097202	total: 19.7s	remaining: 39.3s
# 334:	learn: 6.3096693	total: 19.8s	remaining: 39.3s
# 335:	learn: 6.3095878	total: 19.8s	remaining: 39.2s
# 336:	learn: 6.3095297	total: 19.9s	remaining: 39.2s
# 337:	learn: 6.3094128	total: 20s	remaining: 39.1s
# 338:	learn: 6.3092939	total: 20s	remaining: 39.1s
# 339:	learn: 6.3092009	total: 20.1s	remaining: 39s
# 340:	learn: 6.3091990	total: 20.1s	remaining: 38.9s
# 341:	learn: 6.3091179	total: 20.2s	remaining: 38.8s
# 342:	learn: 6.3090224	total: 20.2s	remaining: 38.8s
# 343:	learn: 6.3089650	total: 20.3s	remaining: 38.7s
# 344:	learn: 6.3088877	total: 20.4s	remaining: 38.7s
# 345:	learn: 6.3088014	total: 20.4s	remaining: 38.6s
# 346:	learn: 6.3086898	total: 20.5s	remaining: 38.6s
# 347:	learn: 6.3085400	total: 20.5s	remaining: 38.5s
# 348:	learn: 6.3085003	total: 20.6s	remaining: 38.4s
# 349:	learn: 6.3084302	total: 20.7s	remaining: 38.4s
# 350:	learn: 6.3083595	total: 20.7s	remaining: 38.3s
# 351:	learn: 6.3083065	total: 20.8s	remaining: 38.3s
# 352:	learn: 6.3081850	total: 20.9s	remaining: 38.2s
# 353:	learn: 6.3081421	total: 20.9s	remaining: 38.2s
# 354:	learn: 6.3080270	total: 21s	remaining: 38.1s
# 355:	learn: 6.3079835	total: 21s	remaining: 38s
# 356:	learn: 6.3079826	total: 21.1s	remaining: 37.9s
# 357:	learn: 6.3079166	total: 21.1s	remaining: 37.9s
# 358:	learn: 6.3077846	total: 21.2s	remaining: 37.8s
# 359:	learn: 6.3077351	total: 21.2s	remaining: 37.8s
# 360:	learn: 6.3076977	total: 21.3s	remaining: 37.7s
# 361:	learn: 6.3075961	total: 21.4s	remaining: 37.7s
# 362:	learn: 6.3075422	total: 21.4s	remaining: 37.6s
# 363:	learn: 6.3074652	total: 21.5s	remaining: 37.6s
# 364:	learn: 6.3073706	total: 21.6s	remaining: 37.5s
# 365:	learn: 6.3072694	total: 21.6s	remaining: 37.4s
# 366:	learn: 6.3071939	total: 21.7s	remaining: 37.4s
# 367:	learn: 6.3071212	total: 21.7s	remaining: 37.3s
# 368:	learn: 6.3070161	total: 21.8s	remaining: 37.3s
# 369:	learn: 6.3070103	total: 21.8s	remaining: 37.2s
# 370:	learn: 6.3069343	total: 21.9s	remaining: 37.1s
# 371:	learn: 6.3068424	total: 22s	remaining: 37.1s
# 372:	learn: 6.3068043	total: 22s	remaining: 37s
# 373:	learn: 6.3066919	total: 22.1s	remaining: 37s
# 374:	learn: 6.3066166	total: 22.1s	remaining: 36.9s
# 375:	learn: 6.3064801	total: 22.2s	remaining: 36.9s
# 376:	learn: 6.3064120	total: 22.3s	remaining: 36.8s
# 377:	learn: 6.3063174	total: 22.3s	remaining: 36.8s
# 378:	learn: 6.3062740	total: 22.4s	remaining: 36.7s
# 379:	learn: 6.3062130	total: 22.5s	remaining: 36.6s
# 380:	learn: 6.3061148	total: 22.5s	remaining: 36.6s
# 381:	learn: 6.3060737	total: 22.6s	remaining: 36.5s
# 382:	learn: 6.3059745	total: 22.6s	remaining: 36.5s
# 383:	learn: 6.3058763	total: 22.7s	remaining: 36.4s
# 384:	learn: 6.3057561	total: 22.8s	remaining: 36.3s
# 385:	learn: 6.3057034	total: 22.8s	remaining: 36.3s
# 386:	learn: 6.3056736	total: 22.9s	remaining: 36.2s
# 387:	learn: 6.3056098	total: 22.9s	remaining: 36.2s
# 388:	learn: 6.3055697	total: 23s	remaining: 36.1s
# 389:	learn: 6.3054235	total: 23s	remaining: 36s
# 390:	learn: 6.3053200	total: 23.1s	remaining: 36s
# 391:	learn: 6.3052664	total: 23.2s	remaining: 36s
# 392:	learn: 6.3051683	total: 23.2s	remaining: 35.9s
# 393:	learn: 6.3050910	total: 23.3s	remaining: 35.8s
# 394:	learn: 6.3050222	total: 23.4s	remaining: 35.8s
# 395:	learn: 6.3048779	total: 23.4s	remaining: 35.7s
# 396:	learn: 6.3048026	total: 23.5s	remaining: 35.7s
# 397:	learn: 6.3047786	total: 23.5s	remaining: 35.6s
# 398:	learn: 6.3046752	total: 23.6s	remaining: 35.5s
# 399:	learn: 6.3046363	total: 23.7s	remaining: 35.5s
# 400:	learn: 6.3045739	total: 23.7s	remaining: 35.4s
# 401:	learn: 6.3044195	total: 23.8s	remaining: 35.4s
# 402:	learn: 6.3043596	total: 23.8s	remaining: 35.3s
# 403:	learn: 6.3042869	total: 23.9s	remaining: 35.3s
# 404:	learn: 6.3041952	total: 24s	remaining: 35.2s
# 405:	learn: 6.3041414	total: 24s	remaining: 35.1s
# 406:	learn: 6.3040483	total: 24.1s	remaining: 35.1s
# 407:	learn: 6.3039566	total: 24.1s	remaining: 35s
# 408:	learn: 6.3038406	total: 24.2s	remaining: 35s
# 409:	learn: 6.3037738	total: 24.3s	remaining: 34.9s
# 410:	learn: 6.3036125	total: 24.3s	remaining: 34.9s
# 411:	learn: 6.3034816	total: 24.4s	remaining: 34.8s
# 412:	learn: 6.3033833	total: 24.4s	remaining: 34.7s
# 413:	learn: 6.3033529	total: 24.5s	remaining: 34.7s
# 414:	learn: 6.3032624	total: 24.6s	remaining: 34.6s
# 415:	learn: 6.3031070	total: 24.6s	remaining: 34.6s
# 416:	learn: 6.3030087	total: 24.7s	remaining: 34.5s
# 417:	learn: 6.3029171	total: 24.7s	remaining: 34.5s
# 418:	learn: 6.3027887	total: 24.8s	remaining: 34.4s
# 419:	learn: 6.3027456	total: 24.9s	remaining: 34.3s
# 420:	learn: 6.3026371	total: 24.9s	remaining: 34.3s
# 421:	learn: 6.3025541	total: 25s	remaining: 34.2s
# 422:	learn: 6.3024695	total: 25s	remaining: 34.2s
# 423:	learn: 6.3023341	total: 25.1s	remaining: 34.1s
# 424:	learn: 6.3021885	total: 25.2s	remaining: 34.1s
# 425:	learn: 6.3021051	total: 25.2s	remaining: 34s
# 426:	learn: 6.3020615	total: 25.3s	remaining: 33.9s
# 427:	learn: 6.3019448	total: 25.4s	remaining: 33.9s
# 428:	learn: 6.3019084	total: 25.4s	remaining: 33.8s
# 429:	learn: 6.3017822	total: 25.5s	remaining: 33.8s
# 430:	learn: 6.3017360	total: 25.5s	remaining: 33.7s
# 431:	learn: 6.3016310	total: 25.6s	remaining: 33.6s
# 432:	learn: 6.3015497	total: 25.6s	remaining: 33.6s
# 433:	learn: 6.3014235	total: 25.7s	remaining: 33.5s
# 434:	learn: 6.3013222	total: 25.8s	remaining: 33.5s
# 435:	learn: 6.3011854	total: 25.8s	remaining: 33.4s
# 436:	learn: 6.3010867	total: 25.9s	remaining: 33.4s
# 437:	learn: 6.3009894	total: 26s	remaining: 33.3s
# 438:	learn: 6.3008955	total: 26.1s	remaining: 33.3s
# 439:	learn: 6.3008074	total: 26.1s	remaining: 33.3s
# 440:	learn: 6.3007314	total: 26.2s	remaining: 33.2s
# 441:	learn: 6.3006581	total: 26.3s	remaining: 33.2s
# 442:	learn: 6.3005681	total: 26.3s	remaining: 33.1s
# 443:	learn: 6.3004794	total: 26.4s	remaining: 33.1s
# 444:	learn: 6.3004004	total: 26.5s	remaining: 33s
# 445:	learn: 6.3002675	total: 26.5s	remaining: 32.9s
# 446:	learn: 6.3002439	total: 26.6s	remaining: 32.9s
# 447:	learn: 6.3001584	total: 26.6s	remaining: 32.8s
# 448:	learn: 6.3000809	total: 26.7s	remaining: 32.8s
# 449:	learn: 6.2999795	total: 26.8s	remaining: 32.7s
# 450:	learn: 6.2998597	total: 26.8s	remaining: 32.7s
# 451:	learn: 6.2997803	total: 26.9s	remaining: 32.6s
# 452:	learn: 6.2996824	total: 27s	remaining: 32.6s
# 453:	learn: 6.2995805	total: 27s	remaining: 32.5s
# 454:	learn: 6.2994419	total: 27.1s	remaining: 32.4s
# 455:	learn: 6.2993039	total: 27.1s	remaining: 32.4s
# 456:	learn: 6.2992321	total: 27.2s	remaining: 32.3s
# 457:	learn: 6.2991701	total: 27.3s	remaining: 32.3s
# 458:	learn: 6.2990715	total: 27.3s	remaining: 32.2s
# 459:	learn: 6.2989990	total: 27.4s	remaining: 32.2s
# 460:	learn: 6.2988765	total: 27.5s	remaining: 32.1s
# 461:	learn: 6.2988326	total: 27.5s	remaining: 32.1s
# 462:	learn: 6.2987431	total: 27.6s	remaining: 32s
# 463:	learn: 6.2986545	total: 27.7s	remaining: 32s
# 464:	learn: 6.2985633	total: 27.7s	remaining: 31.9s
# 465:	learn: 6.2984776	total: 27.8s	remaining: 31.8s
# 466:	learn: 6.2983870	total: 27.9s	remaining: 31.8s
# 467:	learn: 6.2983172	total: 27.9s	remaining: 31.7s
# 468:	learn: 6.2982089	total: 28s	remaining: 31.7s
# 469:	learn: 6.2980886	total: 28.1s	remaining: 31.6s
# 470:	learn: 6.2979684	total: 28.1s	remaining: 31.6s
# 471:	learn: 6.2978366	total: 28.2s	remaining: 31.5s
# 472:	learn: 6.2977494	total: 28.3s	remaining: 31.5s
# 473:	learn: 6.2976879	total: 28.3s	remaining: 31.4s
# 474:	learn: 6.2976015	total: 28.4s	remaining: 31.4s
# 475:	learn: 6.2975419	total: 28.4s	remaining: 31.3s
# 476:	learn: 6.2974385	total: 28.5s	remaining: 31.3s
# 477:	learn: 6.2972815	total: 28.6s	remaining: 31.2s
# 478:	learn: 6.2971423	total: 28.6s	remaining: 31.1s
# 479:	learn: 6.2970507	total: 28.7s	remaining: 31.1s
# 480:	learn: 6.2969294	total: 28.8s	remaining: 31s
# 481:	learn: 6.2968325	total: 28.8s	remaining: 31s
# 482:	learn: 6.2967537	total: 28.9s	remaining: 30.9s
# 483:	learn: 6.2966570	total: 28.9s	remaining: 30.9s
# 484:	learn: 6.2964908	total: 29s	remaining: 30.8s
# 485:	learn: 6.2964204	total: 29.1s	remaining: 30.7s
# 486:	learn: 6.2963216	total: 29.1s	remaining: 30.7s
# 487:	learn: 6.2961897	total: 29.2s	remaining: 30.6s
# 488:	learn: 6.2960621	total: 29.3s	remaining: 30.6s
# 489:	learn: 6.2958944	total: 29.3s	remaining: 30.5s
# 490:	learn: 6.2958222	total: 29.4s	remaining: 30.5s
# 491:	learn: 6.2956766	total: 29.4s	remaining: 30.4s
# 492:	learn: 6.2955854	total: 29.5s	remaining: 30.3s
# 493:	learn: 6.2954324	total: 29.6s	remaining: 30.3s
# 494:	learn: 6.2953710	total: 29.6s	remaining: 30.2s
# 495:	learn: 6.2953177	total: 29.7s	remaining: 30.2s
# 496:	learn: 6.2952198	total: 29.8s	remaining: 30.1s
# 497:	learn: 6.2951609	total: 29.8s	remaining: 30.1s
# 498:	learn: 6.2950868	total: 29.9s	remaining: 30s
# 499:	learn: 6.2950367	total: 30s	remaining: 30s
# 500:	learn: 6.2949435	total: 30s	remaining: 29.9s
# 501:	learn: 6.2948266	total: 30.1s	remaining: 29.8s
# 502:	learn: 6.2947368	total: 30.2s	remaining: 29.8s
# 503:	learn: 6.2946248	total: 30.2s	remaining: 29.7s
# 504:	learn: 6.2945699	total: 30.3s	remaining: 29.7s
# 505:	learn: 6.2944285	total: 30.4s	remaining: 29.6s
# 506:	learn: 6.2943193	total: 30.4s	remaining: 29.6s
# 507:	learn: 6.2942169	total: 30.5s	remaining: 29.5s
# 508:	learn: 6.2941010	total: 30.5s	remaining: 29.5s
# 509:	learn: 6.2940444	total: 30.6s	remaining: 29.4s
# 510:	learn: 6.2938726	total: 30.7s	remaining: 29.3s
# 511:	learn: 6.2938133	total: 30.7s	remaining: 29.3s
# 512:	learn: 6.2936981	total: 30.8s	remaining: 29.2s
# 513:	learn: 6.2936198	total: 30.9s	remaining: 29.2s
# 514:	learn: 6.2935536	total: 30.9s	remaining: 29.1s
# 515:	learn: 6.2934323	total: 31s	remaining: 29.1s
# 516:	learn: 6.2933306	total: 31.1s	remaining: 29s
# 517:	learn: 6.2932006	total: 31.1s	remaining: 29s
# 518:	learn: 6.2931288	total: 31.2s	remaining: 28.9s
# 519:	learn: 6.2930866	total: 31.2s	remaining: 28.8s
# 520:	learn: 6.2929500	total: 31.3s	remaining: 28.8s
# 521:	learn: 6.2928650	total: 31.4s	remaining: 28.8s
# 522:	learn: 6.2927530	total: 31.5s	remaining: 28.7s
# 523:	learn: 6.2927238	total: 31.5s	remaining: 28.6s
# 524:	learn: 6.2926164	total: 31.6s	remaining: 28.6s
# 525:	learn: 6.2924970	total: 31.6s	remaining: 28.5s
# 526:	learn: 6.2923959	total: 31.7s	remaining: 28.5s
# 527:	learn: 6.2922346	total: 31.8s	remaining: 28.4s
# 528:	learn: 6.2922021	total: 31.8s	remaining: 28.3s
# 529:	learn: 6.2921509	total: 31.9s	remaining: 28.3s
# 530:	learn: 6.2920381	total: 32s	remaining: 28.2s
# 531:	learn: 6.2918533	total: 32s	remaining: 28.2s
# 532:	learn: 6.2917563	total: 32.1s	remaining: 28.1s
# 533:	learn: 6.2916893	total: 32.1s	remaining: 28.1s
# 534:	learn: 6.2916286	total: 32.2s	remaining: 28s
# 535:	learn: 6.2915140	total: 32.3s	remaining: 27.9s
# 536:	learn: 6.2914386	total: 32.3s	remaining: 27.9s
# 537:	learn: 6.2913254	total: 32.4s	remaining: 27.8s
# 538:	learn: 6.2912339	total: 32.5s	remaining: 27.8s
# 539:	learn: 6.2911199	total: 32.5s	remaining: 27.7s
# 540:	learn: 6.2910175	total: 32.6s	remaining: 27.6s
# 541:	learn: 6.2909551	total: 32.6s	remaining: 27.6s
# 542:	learn: 6.2908608	total: 32.7s	remaining: 27.5s
# 543:	learn: 6.2907055	total: 32.8s	remaining: 27.5s
# 544:	learn: 6.2906289	total: 32.8s	remaining: 27.4s
# 545:	learn: 6.2904979	total: 32.9s	remaining: 27.3s
# 546:	learn: 6.2904247	total: 32.9s	remaining: 27.3s
# 547:	learn: 6.2903591	total: 33s	remaining: 27.2s
# 548:	learn: 6.2901858	total: 33.1s	remaining: 27.2s
# 549:	learn: 6.2900807	total: 33.1s	remaining: 27.1s
# 550:	learn: 6.2899159	total: 33.2s	remaining: 27.1s
# 551:	learn: 6.2898606	total: 33.3s	remaining: 27s
# 552:	learn: 6.2897299	total: 33.3s	remaining: 26.9s
# 553:	learn: 6.2896339	total: 33.4s	remaining: 26.9s
# 554:	learn: 6.2894923	total: 33.4s	remaining: 26.8s
# 555:	learn: 6.2894305	total: 33.5s	remaining: 26.8s
# 556:	learn: 6.2892984	total: 33.6s	remaining: 26.7s
# 557:	learn: 6.2892062	total: 33.6s	remaining: 26.6s
# 558:	learn: 6.2890938	total: 33.7s	remaining: 26.6s
# 559:	learn: 6.2889291	total: 33.8s	remaining: 26.5s
# 560:	learn: 6.2888492	total: 33.8s	remaining: 26.5s
# 561:	learn: 6.2886628	total: 33.9s	remaining: 26.4s
# 562:	learn: 6.2885480	total: 33.9s	remaining: 26.4s
# 563:	learn: 6.2884345	total: 34s	remaining: 26.3s
# 564:	learn: 6.2882943	total: 34.1s	remaining: 26.2s
# 565:	learn: 6.2881552	total: 34.1s	remaining: 26.2s
# 566:	learn: 6.2880804	total: 34.2s	remaining: 26.1s
# 567:	learn: 6.2879247	total: 34.3s	remaining: 26.1s
# 568:	learn: 6.2878940	total: 34.3s	remaining: 26s
# 569:	learn: 6.2877812	total: 34.4s	remaining: 25.9s
# 570:	learn: 6.2876964	total: 34.5s	remaining: 25.9s
# 571:	learn: 6.2876510	total: 34.5s	remaining: 25.8s
# 572:	learn: 6.2875341	total: 34.6s	remaining: 25.8s
# 573:	learn: 6.2873831	total: 34.6s	remaining: 25.7s
# 574:	learn: 6.2873015	total: 34.7s	remaining: 25.7s
# 575:	learn: 6.2872167	total: 34.8s	remaining: 25.6s
# 576:	learn: 6.2871345	total: 34.8s	remaining: 25.5s
# 577:	learn: 6.2870156	total: 34.9s	remaining: 25.5s
# 578:	learn: 6.2869418	total: 35s	remaining: 25.4s
# 579:	learn: 6.2868206	total: 35s	remaining: 25.4s
# 580:	learn: 6.2867366	total: 35.1s	remaining: 25.3s
# 581:	learn: 6.2866553	total: 35.2s	remaining: 25.3s
# 582:	learn: 6.2865445	total: 35.2s	remaining: 25.2s
# 583:	learn: 6.2864312	total: 35.3s	remaining: 25.2s
# 584:	learn: 6.2863117	total: 35.4s	remaining: 25.1s
# 585:	learn: 6.2861670	total: 35.4s	remaining: 25s
# 586:	learn: 6.2860305	total: 35.5s	remaining: 25s
# 587:	learn: 6.2859397	total: 35.6s	remaining: 24.9s
# 588:	learn: 6.2859019	total: 35.6s	remaining: 24.9s
# 589:	learn: 6.2858178	total: 35.7s	remaining: 24.8s
# 590:	learn: 6.2857036	total: 35.8s	remaining: 24.7s
# 591:	learn: 6.2855756	total: 35.8s	remaining: 24.7s
# 592:	learn: 6.2854237	total: 35.9s	remaining: 24.6s
# 593:	learn: 6.2853576	total: 36s	remaining: 24.6s
# 594:	learn: 6.2852294	total: 36s	remaining: 24.5s
# 595:	learn: 6.2851218	total: 36.1s	remaining: 24.5s
# 596:	learn: 6.2850471	total: 36.1s	remaining: 24.4s
# 597:	learn: 6.2849666	total: 36.2s	remaining: 24.3s
# 598:	learn: 6.2848198	total: 36.3s	remaining: 24.3s
# 599:	learn: 6.2847548	total: 36.3s	remaining: 24.2s
# 600:	learn: 6.2847238	total: 36.4s	remaining: 24.2s
# 601:	learn: 6.2846024	total: 36.5s	remaining: 24.1s
# 602:	learn: 6.2844883	total: 36.5s	remaining: 24.1s
# 603:	learn: 6.2843747	total: 36.6s	remaining: 24s
# 604:	learn: 6.2842740	total: 36.7s	remaining: 23.9s
# 605:	learn: 6.2841625	total: 36.7s	remaining: 23.9s
# 606:	learn: 6.2841179	total: 36.8s	remaining: 23.8s
# 607:	learn: 6.2840481	total: 36.9s	remaining: 23.8s
# 608:	learn: 6.2839103	total: 36.9s	remaining: 23.7s
# 609:	learn: 6.2837844	total: 37s	remaining: 23.6s
# 610:	learn: 6.2837171	total: 37.1s	remaining: 23.6s
# 611:	learn: 6.2836592	total: 37.1s	remaining: 23.5s
# 612:	learn: 6.2835487	total: 37.2s	remaining: 23.5s
# 613:	learn: 6.2834375	total: 37.2s	remaining: 23.4s
# 614:	learn: 6.2832878	total: 37.3s	remaining: 23.4s
# 615:	learn: 6.2831603	total: 37.4s	remaining: 23.3s
# 616:	learn: 6.2830500	total: 37.4s	remaining: 23.2s
# 617:	learn: 6.2829304	total: 37.5s	remaining: 23.2s
# 618:	learn: 6.2828492	total: 37.6s	remaining: 23.1s
# 619:	learn: 6.2827880	total: 37.6s	remaining: 23.1s
# 620:	learn: 6.2826778	total: 37.7s	remaining: 23s
# 621:	learn: 6.2825742	total: 37.8s	remaining: 22.9s
# 622:	learn: 6.2824711	total: 37.8s	remaining: 22.9s
# 623:	learn: 6.2823732	total: 37.9s	remaining: 22.8s
# 624:	learn: 6.2822721	total: 38s	remaining: 22.8s
# 625:	learn: 6.2821733	total: 38s	remaining: 22.7s
# 626:	learn: 6.2821303	total: 38.1s	remaining: 22.7s
# 627:	learn: 6.2820180	total: 38.1s	remaining: 22.6s
# 628:	learn: 6.2819878	total: 38.2s	remaining: 22.5s
# 629:	learn: 6.2819282	total: 38.3s	remaining: 22.5s
# 630:	learn: 6.2818442	total: 38.3s	remaining: 22.4s
# 631:	learn: 6.2817337	total: 38.4s	remaining: 22.3s
# 632:	learn: 6.2816548	total: 38.4s	remaining: 22.3s
# 633:	learn: 6.2816074	total: 38.5s	remaining: 22.2s
# 634:	learn: 6.2815000	total: 38.6s	remaining: 22.2s
# 635:	learn: 6.2813486	total: 38.6s	remaining: 22.1s
# 636:	learn: 6.2812403	total: 38.7s	remaining: 22.1s
# 637:	learn: 6.2812032	total: 38.8s	remaining: 22s
# 638:	learn: 6.2811315	total: 38.8s	remaining: 21.9s
# 639:	learn: 6.2810242	total: 38.9s	remaining: 21.9s
# 640:	learn: 6.2809238	total: 39s	remaining: 21.8s
# 641:	learn: 6.2807816	total: 39s	remaining: 21.8s
# 642:	learn: 6.2806586	total: 39.1s	remaining: 21.7s
# 643:	learn: 6.2805396	total: 39.2s	remaining: 21.6s
# 644:	learn: 6.2804552	total: 39.2s	remaining: 21.6s
# 645:	learn: 6.2803519	total: 39.3s	remaining: 21.5s
# 646:	learn: 6.2802669	total: 39.4s	remaining: 21.5s
# 647:	learn: 6.2801690	total: 39.4s	remaining: 21.4s
# 648:	learn: 6.2800636	total: 39.5s	remaining: 21.4s
# 649:	learn: 6.2800018	total: 39.6s	remaining: 21.3s
# 650:	learn: 6.2799037	total: 39.6s	remaining: 21.2s
# 651:	learn: 6.2798302	total: 39.7s	remaining: 21.2s
# 652:	learn: 6.2797353	total: 39.7s	remaining: 21.1s
# 653:	learn: 6.2796468	total: 39.8s	remaining: 21.1s
# 654:	learn: 6.2795872	total: 39.9s	remaining: 21s
# 655:	learn: 6.2794765	total: 39.9s	remaining: 20.9s
# 656:	learn: 6.2793687	total: 40s	remaining: 20.9s
# 657:	learn: 6.2792795	total: 40.1s	remaining: 20.8s
# 658:	learn: 6.2792547	total: 40.1s	remaining: 20.8s
# 659:	learn: 6.2791893	total: 40.2s	remaining: 20.7s
# 660:	learn: 6.2790563	total: 40.3s	remaining: 20.7s
# 661:	learn: 6.2789815	total: 40.3s	remaining: 20.6s
# 662:	learn: 6.2789123	total: 40.4s	remaining: 20.5s
# 663:	learn: 6.2788092	total: 40.5s	remaining: 20.5s
# 664:	learn: 6.2787627	total: 40.5s	remaining: 20.4s
# 665:	learn: 6.2786355	total: 40.6s	remaining: 20.4s
# 666:	learn: 6.2785886	total: 40.7s	remaining: 20.3s
# 667:	learn: 6.2784746	total: 40.7s	remaining: 20.2s
# 668:	learn: 6.2784289	total: 40.8s	remaining: 20.2s
# 669:	learn: 6.2783750	total: 40.9s	remaining: 20.1s
# 670:	learn: 6.2783010	total: 40.9s	remaining: 20.1s
# 671:	learn: 6.2782628	total: 41s	remaining: 20s
# 672:	learn: 6.2782461	total: 41s	remaining: 19.9s
# 673:	learn: 6.2781270	total: 41.1s	remaining: 19.9s
# 674:	learn: 6.2780565	total: 41.2s	remaining: 19.8s
# 675:	learn: 6.2779670	total: 41.2s	remaining: 19.8s
# 676:	learn: 6.2779473	total: 41.3s	remaining: 19.7s
# 677:	learn: 6.2778316	total: 41.3s	remaining: 19.6s
# 678:	learn: 6.2777398	total: 41.4s	remaining: 19.6s
# 679:	learn: 6.2776031	total: 41.5s	remaining: 19.5s
# 680:	learn: 6.2774643	total: 41.6s	remaining: 19.5s
# 681:	learn: 6.2773398	total: 41.6s	remaining: 19.4s
# 682:	learn: 6.2772568	total: 41.7s	remaining: 19.3s
# 683:	learn: 6.2770969	total: 41.7s	remaining: 19.3s
# 684:	learn: 6.2770275	total: 41.8s	remaining: 19.2s
# 685:	learn: 6.2769800	total: 41.9s	remaining: 19.2s
# 686:	learn: 6.2769452	total: 41.9s	remaining: 19.1s
# 687:	learn: 6.2768622	total: 42s	remaining: 19s
# 688:	learn: 6.2767483	total: 42.1s	remaining: 19s
# 689:	learn: 6.2766778	total: 42.1s	remaining: 18.9s
# 690:	learn: 6.2765686	total: 42.2s	remaining: 18.9s
# 691:	learn: 6.2765042	total: 42.3s	remaining: 18.8s
# 692:	learn: 6.2764088	total: 42.3s	remaining: 18.8s
# 693:	learn: 6.2763351	total: 42.4s	remaining: 18.7s
# 694:	learn: 6.2762681	total: 42.5s	remaining: 18.6s
# 695:	learn: 6.2761564	total: 42.5s	remaining: 18.6s
# 696:	learn: 6.2761234	total: 42.6s	remaining: 18.5s
# 697:	learn: 6.2760597	total: 42.6s	remaining: 18.5s
# 698:	learn: 6.2759763	total: 42.7s	remaining: 18.4s
# 699:	learn: 6.2759283	total: 42.8s	remaining: 18.3s
# 700:	learn: 6.2758456	total: 42.8s	remaining: 18.3s
# 701:	learn: 6.2757646	total: 42.9s	remaining: 18.2s
# 702:	learn: 6.2756997	total: 43s	remaining: 18.2s
# 703:	learn: 6.2756275	total: 43s	remaining: 18.1s
# 704:	learn: 6.2754752	total: 43.1s	remaining: 18s
# 705:	learn: 6.2753859	total: 43.2s	remaining: 18s
# 706:	learn: 6.2753140	total: 43.2s	remaining: 17.9s
# 707:	learn: 6.2752188	total: 43.3s	remaining: 17.9s
# 708:	learn: 6.2751146	total: 43.4s	remaining: 17.8s
# 709:	learn: 6.2750530	total: 43.4s	remaining: 17.7s
# 710:	learn: 6.2749801	total: 43.5s	remaining: 17.7s
# 711:	learn: 6.2749173	total: 43.6s	remaining: 17.6s
# 712:	learn: 6.2748673	total: 43.6s	remaining: 17.6s
# 713:	learn: 6.2747948	total: 43.7s	remaining: 17.5s
# 714:	learn: 6.2747409	total: 43.7s	remaining: 17.4s
# 715:	learn: 6.2746943	total: 43.8s	remaining: 17.4s
# 716:	learn: 6.2746496	total: 43.9s	remaining: 17.3s
# 717:	learn: 6.2745682	total: 43.9s	remaining: 17.3s
# 718:	learn: 6.2744751	total: 44s	remaining: 17.2s
# 719:	learn: 6.2744475	total: 44.1s	remaining: 17.1s
# 720:	learn: 6.2744206	total: 44.1s	remaining: 17.1s
# 721:	learn: 6.2743367	total: 44.2s	remaining: 17s
# 722:	learn: 6.2742569	total: 44.2s	remaining: 17s
# 723:	learn: 6.2741583	total: 44.3s	remaining: 16.9s
# 724:	learn: 6.2740658	total: 44.4s	remaining: 16.8s
# 725:	learn: 6.2739608	total: 44.4s	remaining: 16.8s
# 726:	learn: 6.2738766	total: 44.5s	remaining: 16.7s
# 727:	learn: 6.2738134	total: 44.6s	remaining: 16.7s
# 728:	learn: 6.2737395	total: 44.6s	remaining: 16.6s
# 729:	learn: 6.2736267	total: 44.7s	remaining: 16.5s
# 730:	learn: 6.2735339	total: 44.8s	remaining: 16.5s
# 731:	learn: 6.2734053	total: 44.8s	remaining: 16.4s
# 732:	learn: 6.2733415	total: 44.9s	remaining: 16.4s
# 733:	learn: 6.2732581	total: 45s	remaining: 16.3s
# 734:	learn: 6.2731624	total: 45s	remaining: 16.2s
# 735:	learn: 6.2730867	total: 45.1s	remaining: 16.2s
# 736:	learn: 6.2730258	total: 45.2s	remaining: 16.1s
# 737:	learn: 6.2729779	total: 45.2s	remaining: 16.1s
# 738:	learn: 6.2728785	total: 45.3s	remaining: 16s
# 739:	learn: 6.2727658	total: 45.3s	remaining: 15.9s
# 740:	learn: 6.2727367	total: 45.4s	remaining: 15.9s
# 741:	learn: 6.2726581	total: 45.5s	remaining: 15.8s
# 742:	learn: 6.2725967	total: 45.5s	remaining: 15.7s
# 743:	learn: 6.2725367	total: 45.6s	remaining: 15.7s
# 744:	learn: 6.2724367	total: 45.7s	remaining: 15.6s
# 745:	learn: 6.2723830	total: 45.7s	remaining: 15.6s
# 746:	learn: 6.2722683	total: 45.8s	remaining: 15.5s
# 747:	learn: 6.2722387	total: 45.9s	remaining: 15.4s
# 748:	learn: 6.2721539	total: 45.9s	remaining: 15.4s
# 749:	learn: 6.2719901	total: 46s	remaining: 15.3s
# 750:	learn: 6.2718881	total: 46.1s	remaining: 15.3s
# 751:	learn: 6.2717972	total: 46.1s	remaining: 15.2s
# 752:	learn: 6.2717635	total: 46.2s	remaining: 15.1s
# 753:	learn: 6.2717139	total: 46.2s	remaining: 15.1s
# 754:	learn: 6.2716387	total: 46.3s	remaining: 15s
# 755:	learn: 6.2715678	total: 46.4s	remaining: 15s
# 756:	learn: 6.2714818	total: 46.4s	remaining: 14.9s
# 757:	learn: 6.2713187	total: 46.5s	remaining: 14.8s
# 758:	learn: 6.2712642	total: 46.6s	remaining: 14.8s
# 759:	learn: 6.2712075	total: 46.6s	remaining: 14.7s
# 760:	learn: 6.2711449	total: 46.7s	remaining: 14.7s
# 761:	learn: 6.2710852	total: 46.8s	remaining: 14.6s
# 762:	learn: 6.2710542	total: 46.8s	remaining: 14.5s
# 763:	learn: 6.2709934	total: 46.9s	remaining: 14.5s
# 764:	learn: 6.2709118	total: 47s	remaining: 14.4s
# 765:	learn: 6.2708281	total: 47s	remaining: 14.4s
# 766:	learn: 6.2707186	total: 47.1s	remaining: 14.3s
# 767:	learn: 6.2706130	total: 47.2s	remaining: 14.2s
# 768:	learn: 6.2705543	total: 47.2s	remaining: 14.2s
# 769:	learn: 6.2704965	total: 47.3s	remaining: 14.1s
# 770:	learn: 6.2704401	total: 47.4s	remaining: 14.1s
# 771:	learn: 6.2704081	total: 47.4s	remaining: 14s
# 772:	learn: 6.2703431	total: 47.5s	remaining: 13.9s
# 773:	learn: 6.2702459	total: 47.6s	remaining: 13.9s
# 774:	learn: 6.2701146	total: 47.6s	remaining: 13.8s
# 775:	learn: 6.2700717	total: 47.7s	remaining: 13.8s
# 776:	learn: 6.2699988	total: 47.8s	remaining: 13.7s
# 777:	learn: 6.2699112	total: 47.9s	remaining: 13.7s
# 778:	learn: 6.2698364	total: 47.9s	remaining: 13.6s
# 779:	learn: 6.2697548	total: 48s	remaining: 13.5s
# 780:	learn: 6.2697131	total: 48.1s	remaining: 13.5s
# 781:	learn: 6.2696448	total: 48.1s	remaining: 13.4s
# 782:	learn: 6.2695884	total: 48.2s	remaining: 13.4s
# 783:	learn: 6.2695153	total: 48.3s	remaining: 13.3s
# 784:	learn: 6.2694649	total: 48.3s	remaining: 13.2s
# 785:	learn: 6.2693830	total: 48.4s	remaining: 13.2s
# 786:	learn: 6.2692923	total: 48.5s	remaining: 13.1s
# 787:	learn: 6.2692241	total: 48.6s	remaining: 13.1s
# 788:	learn: 6.2691867	total: 48.6s	remaining: 13s
# 789:	learn: 6.2691190	total: 48.7s	remaining: 12.9s
# 790:	learn: 6.2690449	total: 48.8s	remaining: 12.9s
# 791:	learn: 6.2689399	total: 48.8s	remaining: 12.8s
# 792:	learn: 6.2688912	total: 48.9s	remaining: 12.8s
# 793:	learn: 6.2688252	total: 49s	remaining: 12.7s
# 794:	learn: 6.2687469	total: 49s	remaining: 12.6s
# 795:	learn: 6.2686980	total: 49.1s	remaining: 12.6s
# 796:	learn: 6.2686351	total: 49.2s	remaining: 12.5s
# 797:	learn: 6.2685475	total: 49.2s	remaining: 12.5s
# 798:	learn: 6.2684344	total: 49.3s	remaining: 12.4s
# 799:	learn: 6.2684124	total: 49.4s	remaining: 12.3s
# 800:	learn: 6.2683021	total: 49.4s	remaining: 12.3s
# 801:	learn: 6.2681917	total: 49.5s	remaining: 12.2s
# 802:	learn: 6.2681144	total: 49.6s	remaining: 12.2s
# 803:	learn: 6.2680721	total: 49.6s	remaining: 12.1s
# 804:	learn: 6.2680158	total: 49.7s	remaining: 12s
# 805:	learn: 6.2679124	total: 49.8s	remaining: 12s
# 806:	learn: 6.2678605	total: 49.8s	remaining: 11.9s
# 807:	learn: 6.2678071	total: 49.9s	remaining: 11.9s
# 808:	learn: 6.2677119	total: 50s	remaining: 11.8s
# 809:	learn: 6.2676132	total: 50s	remaining: 11.7s
# 810:	learn: 6.2675537	total: 50.1s	remaining: 11.7s
# 811:	learn: 6.2674688	total: 50.2s	remaining: 11.6s
# 812:	learn: 6.2673497	total: 50.2s	remaining: 11.5s
# 813:	learn: 6.2673033	total: 50.3s	remaining: 11.5s
# 814:	learn: 6.2672236	total: 50.3s	remaining: 11.4s
# 815:	learn: 6.2671882	total: 50.4s	remaining: 11.4s
# 816:	learn: 6.2671055	total: 50.5s	remaining: 11.3s
# 817:	learn: 6.2670511	total: 50.5s	remaining: 11.2s
# 818:	learn: 6.2669369	total: 50.6s	remaining: 11.2s
# 819:	learn: 6.2668781	total: 50.6s	remaining: 11.1s
# 820:	learn: 6.2667817	total: 50.7s	remaining: 11.1s
# 821:	learn: 6.2666998	total: 50.8s	remaining: 11s
# 822:	learn: 6.2665548	total: 50.8s	remaining: 10.9s
# 823:	learn: 6.2664469	total: 50.9s	remaining: 10.9s
# 824:	learn: 6.2663999	total: 51s	remaining: 10.8s
# 825:	learn: 6.2663143	total: 51s	remaining: 10.7s
# 826:	learn: 6.2662099	total: 51.1s	remaining: 10.7s
# 827:	learn: 6.2661388	total: 51.2s	remaining: 10.6s
# 828:	learn: 6.2660897	total: 51.2s	remaining: 10.6s
# 829:	learn: 6.2659959	total: 51.3s	remaining: 10.5s
# 830:	learn: 6.2659432	total: 51.4s	remaining: 10.4s
# 831:	learn: 6.2658746	total: 51.4s	remaining: 10.4s
# 832:	learn: 6.2657948	total: 51.5s	remaining: 10.3s
# 833:	learn: 6.2657583	total: 51.6s	remaining: 10.3s
# 834:	learn: 6.2656671	total: 51.6s	remaining: 10.2s
# 835:	learn: 6.2655980	total: 51.7s	remaining: 10.1s
# 836:	learn: 6.2655531	total: 51.7s	remaining: 10.1s
# 837:	learn: 6.2654975	total: 51.8s	remaining: 10s
# 838:	learn: 6.2654373	total: 51.9s	remaining: 9.95s
# 839:	learn: 6.2653339	total: 51.9s	remaining: 9.89s
# 840:	learn: 6.2652339	total: 52s	remaining: 9.83s
# 841:	learn: 6.2651312	total: 52.1s	remaining: 9.77s
# 842:	learn: 6.2650621	total: 52.1s	remaining: 9.71s
# 843:	learn: 6.2649858	total: 52.2s	remaining: 9.65s
# 844:	learn: 6.2649553	total: 52.3s	remaining: 9.58s
# 845:	learn: 6.2648879	total: 52.3s	remaining: 9.52s
# 846:	learn: 6.2648335	total: 52.4s	remaining: 9.46s
# 847:	learn: 6.2647588	total: 52.4s	remaining: 9.4s
# 848:	learn: 6.2646973	total: 52.5s	remaining: 9.34s
# 849:	learn: 6.2646349	total: 52.6s	remaining: 9.28s
# 850:	learn: 6.2645069	total: 52.6s	remaining: 9.22s
# 851:	learn: 6.2644436	total: 52.7s	remaining: 9.15s
# 852:	learn: 6.2643495	total: 52.8s	remaining: 9.09s
# 853:	learn: 6.2643051	total: 52.8s	remaining: 9.03s
# 854:	learn: 6.2642490	total: 52.9s	remaining: 8.97s
# 855:	learn: 6.2641853	total: 52.9s	remaining: 8.91s
# 856:	learn: 6.2641170	total: 53s	remaining: 8.85s
# 857:	learn: 6.2640635	total: 53.1s	remaining: 8.79s
# 858:	learn: 6.2639842	total: 53.2s	remaining: 8.72s
# 859:	learn: 6.2638668	total: 53.2s	remaining: 8.66s
# 860:	learn: 6.2638238	total: 53.3s	remaining: 8.6s
# 861:	learn: 6.2637827	total: 53.3s	remaining: 8.54s
# 862:	learn: 6.2636951	total: 53.4s	remaining: 8.48s
# 863:	learn: 6.2636156	total: 53.5s	remaining: 8.42s
# 864:	learn: 6.2635732	total: 53.5s	remaining: 8.35s
# 865:	learn: 6.2635407	total: 53.6s	remaining: 8.29s
# 866:	learn: 6.2634802	total: 53.7s	remaining: 8.23s
# 867:	learn: 6.2633936	total: 53.7s	remaining: 8.17s
# 868:	learn: 6.2632826	total: 53.8s	remaining: 8.11s
# 869:	learn: 6.2631763	total: 53.9s	remaining: 8.05s
# 870:	learn: 6.2631345	total: 53.9s	remaining: 7.99s
# 871:	learn: 6.2630256	total: 54s	remaining: 7.92s
# 872:	learn: 6.2629750	total: 54s	remaining: 7.86s
# 873:	learn: 6.2628734	total: 54.1s	remaining: 7.8s
# 874:	learn: 6.2628130	total: 54.2s	remaining: 7.74s
# 875:	learn: 6.2626868	total: 54.2s	remaining: 7.68s
# 876:	learn: 6.2625986	total: 54.3s	remaining: 7.62s
# 877:	learn: 6.2625295	total: 54.4s	remaining: 7.55s
# 878:	learn: 6.2624712	total: 54.4s	remaining: 7.49s
# 879:	learn: 6.2623816	total: 54.5s	remaining: 7.43s
# 880:	learn: 6.2622935	total: 54.6s	remaining: 7.37s
# 881:	learn: 6.2622443	total: 54.6s	remaining: 7.31s
# 882:	learn: 6.2621329	total: 54.7s	remaining: 7.25s
# 883:	learn: 6.2620503	total: 54.8s	remaining: 7.18s
# 884:	learn: 6.2619819	total: 54.8s	remaining: 7.12s
# 885:	learn: 6.2618565	total: 54.9s	remaining: 7.06s
# 886:	learn: 6.2618013	total: 55s	remaining: 7s
# 887:	learn: 6.2617448	total: 55s	remaining: 6.94s
# 888:	learn: 6.2616640	total: 55.1s	remaining: 6.88s
# 889:	learn: 6.2616003	total: 55.2s	remaining: 6.82s
# 890:	learn: 6.2615570	total: 55.2s	remaining: 6.75s
# 891:	learn: 6.2614458	total: 55.3s	remaining: 6.69s
# 892:	learn: 6.2613780	total: 55.3s	remaining: 6.63s
# 893:	learn: 6.2613061	total: 55.4s	remaining: 6.57s
# 894:	learn: 6.2612552	total: 55.5s	remaining: 6.51s
# 895:	learn: 6.2611690	total: 55.5s	remaining: 6.45s
# 896:	learn: 6.2611002	total: 55.6s	remaining: 6.38s
# 897:	learn: 6.2610779	total: 55.7s	remaining: 6.32s
# 898:	learn: 6.2610134	total: 55.7s	remaining: 6.26s
# 899:	learn: 6.2609390	total: 55.8s	remaining: 6.2s
# 900:	learn: 6.2608732	total: 55.9s	remaining: 6.14s
# 901:	learn: 6.2607366	total: 55.9s	remaining: 6.08s
# 902:	learn: 6.2607011	total: 56s	remaining: 6.01s
# 903:	learn: 6.2605955	total: 56s	remaining: 5.95s
# 904:	learn: 6.2605208	total: 56.1s	remaining: 5.89s
# 905:	learn: 6.2604481	total: 56.2s	remaining: 5.83s
# 906:	learn: 6.2603561	total: 56.2s	remaining: 5.77s
# 907:	learn: 6.2602995	total: 56.3s	remaining: 5.71s
# 908:	learn: 6.2602613	total: 56.4s	remaining: 5.64s
# 909:	learn: 6.2601577	total: 56.4s	remaining: 5.58s
# 910:	learn: 6.2600930	total: 56.5s	remaining: 5.52s
# 911:	learn: 6.2600316	total: 56.6s	remaining: 5.46s
# 912:	learn: 6.2599882	total: 56.6s	remaining: 5.4s
# 913:	learn: 6.2599386	total: 56.7s	remaining: 5.33s
# 914:	learn: 6.2598584	total: 56.8s	remaining: 5.27s
# 915:	learn: 6.2598062	total: 56.8s	remaining: 5.21s
# 916:	learn: 6.2597629	total: 56.9s	remaining: 5.15s
# 917:	learn: 6.2596838	total: 56.9s	remaining: 5.09s
# 918:	learn: 6.2595977	total: 57s	remaining: 5.02s
# 919:	learn: 6.2595068	total: 57.1s	remaining: 4.96s
# 920:	learn: 6.2594545	total: 57.1s	remaining: 4.9s
# 921:	learn: 6.2593790	total: 57.2s	remaining: 4.84s
# 922:	learn: 6.2593127	total: 57.3s	remaining: 4.78s
# 923:	learn: 6.2592741	total: 57.3s	remaining: 4.71s
# 924:	learn: 6.2591733	total: 57.4s	remaining: 4.65s
# 925:	learn: 6.2591247	total: 57.5s	remaining: 4.59s
# 926:	learn: 6.2590465	total: 57.5s	remaining: 4.53s
# 927:	learn: 6.2589984	total: 57.6s	remaining: 4.47s
# 928:	learn: 6.2589265	total: 57.7s	remaining: 4.41s
# 929:	learn: 6.2588385	total: 57.7s	remaining: 4.34s
# 930:	learn: 6.2587558	total: 57.8s	remaining: 4.28s
# 931:	learn: 6.2586930	total: 57.9s	remaining: 4.22s
# 932:	learn: 6.2586461	total: 57.9s	remaining: 4.16s
# 933:	learn: 6.2585620	total: 58s	remaining: 4.1s
# 934:	learn: 6.2585010	total: 58.1s	remaining: 4.04s
# 935:	learn: 6.2584555	total: 58.2s	remaining: 3.98s
# 936:	learn: 6.2583471	total: 58.2s	remaining: 3.92s
# 937:	learn: 6.2582729	total: 58.3s	remaining: 3.85s
# 938:	learn: 6.2582353	total: 58.4s	remaining: 3.79s
# 939:	learn: 6.2582054	total: 58.4s	remaining: 3.73s
# 940:	learn: 6.2581446	total: 58.5s	remaining: 3.67s
# 941:	learn: 6.2581044	total: 58.6s	remaining: 3.6s
# 942:	learn: 6.2580524	total: 58.6s	remaining: 3.54s
# 943:	learn: 6.2580018	total: 58.7s	remaining: 3.48s
# 944:	learn: 6.2579036	total: 58.8s	remaining: 3.42s
# 945:	learn: 6.2578707	total: 58.8s	remaining: 3.36s
# 946:	learn: 6.2578339	total: 58.9s	remaining: 3.3s
# 947:	learn: 6.2577852	total: 59s	remaining: 3.23s
# 948:	learn: 6.2577165	total: 59s	remaining: 3.17s
# 949:	learn: 6.2576267	total: 59.1s	remaining: 3.11s
# 950:	learn: 6.2575399	total: 59.2s	remaining: 3.05s
# 951:	learn: 6.2574678	total: 59.2s	remaining: 2.99s
# 952:	learn: 6.2573816	total: 59.3s	remaining: 2.92s
# 953:	learn: 6.2572976	total: 59.4s	remaining: 2.86s
# 954:	learn: 6.2572097	total: 59.4s	remaining: 2.8s
# 955:	learn: 6.2571474	total: 59.5s	remaining: 2.74s
# 956:	learn: 6.2570785	total: 59.6s	remaining: 2.67s
# 957:	learn: 6.2569999	total: 59.6s	remaining: 2.61s
# 958:	learn: 6.2569534	total: 59.7s	remaining: 2.55s
# 959:	learn: 6.2568831	total: 59.8s	remaining: 2.49s
# 960:	learn: 6.2567896	total: 59.8s	remaining: 2.43s
# 961:	learn: 6.2567220	total: 59.9s	remaining: 2.37s
# 962:	learn: 6.2566531	total: 60s	remaining: 2.3s
# 963:	learn: 6.2566270	total: 1m	remaining: 2.24s
# 964:	learn: 6.2565986	total: 1m	remaining: 2.18s
# 965:	learn: 6.2565346	total: 1m	remaining: 2.12s
# 966:	learn: 6.2564797	total: 1m	remaining: 2.05s
# 967:	learn: 6.2564296	total: 1m	remaining: 1.99s
# 968:	learn: 6.2563775	total: 1m	remaining: 1.93s
# 969:	learn: 6.2563493	total: 1m	remaining: 1.87s
# 970:	learn: 6.2562632	total: 1m	remaining: 1.8s
# 971:	learn: 6.2561836	total: 1m	remaining: 1.74s
# 972:	learn: 6.2561336	total: 1m	remaining: 1.68s
# 973:	learn: 6.2560660	total: 1m	remaining: 1.62s
# 974:	learn: 6.2560070	total: 1m	remaining: 1.56s
# 975:	learn: 6.2559118	total: 1m	remaining: 1.49s
# 976:	learn: 6.2558404	total: 1m	remaining: 1.43s
# 977:	learn: 6.2557852	total: 1m	remaining: 1.37s
# 978:	learn: 6.2557265	total: 1m	remaining: 1.31s
# 979:	learn: 6.2556506	total: 1m 1s	remaining: 1.25s
# 980:	learn: 6.2555795	total: 1m 1s	remaining: 1.18s
# 981:	learn: 6.2555293	total: 1m 1s	remaining: 1.12s
# 982:	learn: 6.2554443	total: 1m 1s	remaining: 1.06s
# 983:	learn: 6.2554070	total: 1m 1s	remaining: 997ms
# 984:	learn: 6.2553307	total: 1m 1s	remaining: 935ms
# 985:	learn: 6.2552943	total: 1m 1s	remaining: 872ms
# 986:	learn: 6.2552607	total: 1m 1s	remaining: 810ms
# 987:	learn: 6.2552233	total: 1m 1s	remaining: 748ms
# 988:	learn: 6.2551626	total: 1m 1s	remaining: 685ms
# 989:	learn: 6.2550531	total: 1m 1s	remaining: 623ms
# 990:	learn: 6.2550109	total: 1m 1s	remaining: 561ms
# 991:	learn: 6.2548917	total: 1m 1s	remaining: 498ms
# 992:	learn: 6.2548314	total: 1m 1s	remaining: 436ms
# 993:	learn: 6.2547819	total: 1m 1s	remaining: 374ms
# 994:	learn: 6.2546973	total: 1m 2s	remaining: 312ms
# 995:	learn: 6.2546487	total: 1m 2s	remaining: 249ms
# 996:	learn: 6.2545496	total: 1m 2s	remaining: 187ms
# 997:	learn: 6.2544657	total: 1m 2s	remaining: 125ms
# 998:	learn: 6.2543768	total: 1m 2s	remaining: 62.4ms
# 999:	learn: 6.2543110	total: 1m 2s	remaining: 0us

# %% [markdown]
# ### Naive Feature selection model performance
# Now that we have trained and predicted each algorithm, we can finally evaluate their performance to give us a baseline to test on:

# %%
print(f"Linear Regression: {mae_lr:.4f}")
print(f"Random Forest: {mae_rf:.4f}")
print(f"LightGBM: {mae_lgbm:.4f}")
print(f"XGBoost: {mae_xgb:.4f}")
print(f"CatBoost: {mae_cb:.4f}")
# Out:
# Linear Regression: 5.7078
# Random Forest: 6.4311
# LightGBM: 6.3044
# XGBoost: 6.3004
# CatBoost: 6.3020

# %% [markdown]
# Interestingly, we found dropping near price and far price (features that are half null), gave Linear Regression the best score. Among the models that trained on the whole training set, LightGBM had the best MAE. This is a good starting point to see how well we can improve the performance of the last three models. To save time and avoid redundancy, we will not pursue Linear Regression or Random Forest further.
#
# ## Original Feature Engineering
#
# In this section, we will think of and create our own features to try and enhance the performance of the finalist models (LightGBM, XGBoost, and CatBoost).
#
# These are our new and originally made features:
#
# - `wap_volatility`: Measures how much the weighted average price (WAP) swings over 5 time periods for each stock.
#
# - `bid_ask_spread`: Difference between the selling price (ask) and buying price (bid).
#
# - `bid_ask_volatility`: Tracks how much the bid-ask spread varies over 5 time periods for each stock.
#
# - `wap_momentum`: Shows the percentage change in WAP over 3 time periods for each stock.
#
# - `price_momentum`: Shows the percentage change in reference price over 3 time periods for each stock.
#
# - `log_imbalance_size`: Shrinks large imbalance size values (buy/sell order differences) using a log function.
#
# - `log_matched_size`: Shrinks large matched order size values using a log function.
#
# - `log_bid_size`: Shrinks large bid order size values using a log function.
#
# - `log_ask_size`: Shrinks large ask order size values using a log function.
#
# - `bucket_price_interaction`: Multiplies time (seconds in bucket) by reference price to capture their combined effect.
#
# - `bucket_imbalance_interaction`: Multiplies time (seconds in bucket) by imbalance size to capture their combined effect.
#
# - `wap_to_ref_price`: Divides WAP by reference price to show their relative difference.
#
# - `bid_to_ask_price`: Divides bid price by ask price to show their relative difference.

# %%
# Written by Cooper and Attila 
def process_data_with_feature_engineering(data: pd.DataFrame) -> tuple[pd.DataFrame, pd.Series]:
    # Drop rows where 'target' is null, as these cannot be used for training
    data.dropna(subset=["target"], inplace=True)

    # Volatility features
    data['wap_volatility'] = data.groupby('stock_id')['wap'].transform(
        lambda x: x.pct_change().rolling(window=5, min_periods=1).std()
    )
    data['bid_ask_spread'] = data['ask_price'] - data['bid_price']
    data['bid_ask_volatility'] = data.groupby('stock_id')['bid_ask_spread'].transform(
        lambda x: x.rolling(window=5, min_periods=1).std()
    )

    # Momentum features
    data['wap_momentum'] = data.groupby('stock_id')['wap'].transform(
        lambda x: x.pct_change(periods=3)
    )
    data['price_momentum'] = data.groupby('stock_id')['reference_price'].transform(
        lambda x: x.pct_change(periods=3)
    )

    # Log transformations
    size_cols = ['imbalance_size', 'matched_size', 'bid_size', 'ask_size']
    for col in size_cols:
        data[f'log_{col}'] = np.log1p(data[col].clip(lower=0))

    # Time-based interactions
    data['bucket_price_interaction'] = data['seconds_in_bucket'] * data['reference_price']
    data['bucket_imbalance_interaction'] = data['seconds_in_bucket'] * data['imbalance_size']

    # Relative price features
    data['wap_to_ref_price'] = data['wap'] / (data['reference_price'] + 1e-6)
    data['bid_to_ask_price'] = data['bid_price'] / (data['ask_price'] + 1e-6)

    # Handle NaN and inf after feature creation
    # Identify columns that are not identifiers or the target
    cols_to_process = [col for col in data.columns if col not in ['stock_id', 'date_id', 'target', 'time_id', 'row_id']]
    data[cols_to_process] = data[cols_to_process].replace([np.inf, -np.inf], np.nan) # Replace inf with NaN first
    data[cols_to_process] = data[cols_to_process].fillna(data[cols_to_process].median()) # Fill remaining NaNs with median

    # Separate features (X) and target (y)
    X = data.drop("target", axis=1)
    y = data["target"]

    return X, y

# %% [markdown]
# Now we can redo the naive training but with our original features:

# %%
import numpy as np

X, y = process_data_with_feature_engineering(df.copy())

# Split the data into training and validation subsets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=42)

# LightGBM
lgbm_params = {
    'objective': 'regression',
    'metric': 'mae',
    'boosting_type': 'gbdt',
    'learning_rate': 0.03,
    'num_leaves': 31,
    'n_estimators': 2000,
    'min_child_samples': 50,
    'lambda_l1': 0.5,
    'lambda_l2': 0.5,
    'device': 'CPU',
    'random_state': 42,
    'n_jobs': -1
}
mae_lgbm, lgbm_model = train_model(LGBMRegressor, X_train, y_train, X_val, y_val, params=lgbm_params)

# XGBoost
xgb_params = {
    'objective': 'reg:absoluteerror',
    'eval_metric': 'mae',
    'device': "cuda",
    'random_state': 42
}
mae_xgb, xgb_model = train_model(xgboost.XGBRegressor, X_train, y_train, X_val, y_val, params=xgb_params)

# CatBoost
cb_params = {"loss_function": "MAE", "random_state": 42, "verbose": 0, "task_type": "CPU", "thread_count": -1, "cat_features": ['stock_id', 'imbalance_buy_sell_flag']} 
mae_cb, cb_model = train_model(CatBoostRegressor, X_train, y_train, X_val, y_val, params=cb_params)
# Out:
# /var/folders/g0/hx8sq_xn5116f0v3hqmcb0lw0000gn/T/ipykernel_77279/2978197467.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   lambda x: x.pct_change().rolling(window=5, min_periods=1).std()
# /var/folders/g0/hx8sq_xn5116f0v3hqmcb0lw0000gn/T/ipykernel_77279/2978197467.py:17: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   lambda x: x.pct_change(periods=3)
# /var/folders/g0/hx8sq_xn5116f0v3hqmcb0lw0000gn/T/ipykernel_77279/2978197467.py:20: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   lambda x: x.pct_change(periods=3)
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004329 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6631
# [LightGBM] [Info] Number of data points in the train set: 350939, number of used features: 28
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Info] Start training from score -0.026625
# Training until validation scores don't improve for 150 rounds
# [150]	valid_0's l1: 6.29863
# [300]	valid_0's l1: 6.29406
# [450]	valid_0's l1: 6.29231
# [600]	valid_0's l1: 6.29213
# Early stopping, best iteration is:
# [496]	valid_0's l1: 6.29144
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# /Users/bbwalrus/cfrm421-finalproj-1/.venv/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [02:06:11] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:203: XGBoost is not compiled with CUDA support.
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
print(f"LightGBM MAE: {mae_lgbm:.4f}")
print(f"XGBoost MAE: {mae_xgb:.4f}")
print(f"CatBoost MAE: {mae_cb:.4f}")
# Out:
# LightGBM MAE: 6.2914
# XGBoost MAE: 6.2923
# CatBoost MAE: 6.2825

# %% [markdown]
# We are seeing some minor improvements, but not enough to justify that our features are that helpful. Let's use the post processing trick that was used by the 1st place winner, and see how those results compare:

# %% [markdown]
# We applied the post-processing trick used by the Kaggle first-place solution, which corrects each model’s predictions by subtracting the weighted average prediction for each time_id. The weights are based on a predefined stock_weights dictionary reflecting the relative importance or liquidity of each stock.

# %%
# Define stock weights (Given by Kaggle) (Attila, Cooper)
weight_df = pd.DataFrame()
weight_df['stock_id'] = list(range(200))
weight_df['weight'] = [
    0.004, 0.001, 0.002, 0.006, 0.004, 0.004, 0.002, 0.006, 0.006, 0.002, 0.002, 0.008,
    0.006, 0.002, 0.008, 0.006, 0.002, 0.006, 0.004, 0.002, 0.004, 0.001, 0.006, 0.004,
    0.002, 0.002, 0.004, 0.002, 0.004, 0.004, 0.001, 0.001, 0.002, 0.002, 0.006, 0.004,
    0.004, 0.004, 0.006, 0.002, 0.002, 0.04 , 0.002, 0.002, 0.004, 0.04 , 0.002, 0.001,
    0.006, 0.004, 0.004, 0.006, 0.001, 0.004, 0.004, 0.002, 0.006, 0.004, 0.006, 0.004,
    0.006, 0.004, 0.002, 0.001, 0.002, 0.004, 0.002, 0.008, 0.004, 0.004, 0.002, 0.004,
    0.006, 0.002, 0.004, 0.004, 0.002, 0.004, 0.004, 0.004, 0.001, 0.002, 0.002, 0.008,
    0.02 , 0.004, 0.006, 0.002, 0.02 , 0.002, 0.002, 0.006, 0.004, 0.002, 0.001, 0.02,
    0.006, 0.001, 0.002, 0.004, 0.001, 0.002, 0.006, 0.006, 0.004, 0.006, 0.001, 0.002,
    0.004, 0.006, 0.006, 0.001, 0.04 , 0.006, 0.002, 0.004, 0.002, 0.002, 0.006, 0.002,
    0.002, 0.004, 0.006, 0.006, 0.002, 0.002, 0.008, 0.006, 0.004, 0.002, 0.006, 0.002,
    0.004, 0.006, 0.002, 0.004, 0.001, 0.004, 0.002, 0.004, 0.008, 0.006, 0.008, 0.002,
    0.004, 0.002, 0.001, 0.004, 0.004, 0.004, 0.006, 0.008, 0.004, 0.001, 0.001, 0.002,
    0.006, 0.004, 0.001, 0.002, 0.006, 0.004, 0.006, 0.008, 0.002, 0.002, 0.004, 0.002,
    0.04 , 0.002, 0.002, 0.004, 0.002, 0.002, 0.006, 0.02 , 0.004, 0.002, 0.006, 0.02,
    0.001, 0.002, 0.006, 0.004, 0.006, 0.004, 0.004, 0.004, 0.004, 0.002, 0.004, 0.04,
    0.002, 0.008, 0.002, 0.004, 0.001, 0.004, 0.006, 0.004,]
stock_weights = dict(zip(weight_df['stock_id'], weight_df['weight']))

# %%
# Brandon - made universal helper function for post processing

def apply_postprocessing(model, X_val, y_val, stock_weights, model_name="Model"):
    preds_df = pd.DataFrame({
        'prediction': model.predict(X_val),
        'stock_id': X_val['stock_id'],
        'time_id': X_val['time_id']
    })
    preds_df['stock_weights'] = preds_df['stock_id'].map(stock_weights)
    preds_df['weighted_sum'] = preds_df['prediction'] * preds_df['stock_weights']
    
    weighted_avg = preds_df.groupby('time_id')['weighted_sum'].transform('sum') / preds_df.groupby('time_id')['stock_weights'].transform('sum')
    preds_adjusted = preds_df['prediction'] - weighted_avg
    
    mae_adjusted = mean_absolute_error(y_val, preds_adjusted)
    print(f"{model_name} Adjusted MAE: {mae_adjusted:.4f}\n")
    return preds_adjusted, mae_adjusted

print("--- LightGBM post-processing ---")
y_pred_lgbm_adjusted, mae_lgbm_adjusted = apply_postprocessing(lgbm_model, X_val, y_val, stock_weights, "LightGBM")

print("--- XGBoost post-processing ---")
y_pred_xgb_adjusted, mae_xgb_adjusted = apply_postprocessing(xgb_model, X_val, y_val, stock_weights, "XGBoost")

print("--- CatBoost post-processing ---")
y_pred_cb_adjusted, mae_cb_adjusted = apply_postprocessing(cb_model, X_val, y_val, stock_weights, "CatBoost")
# Out:
# --- LightGBM post-processing ---
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# LightGBM Adjusted MAE: 6.3130
#
# --- XGBoost post-processing ---
# XGBoost Adjusted MAE: 6.3160
#
# --- CatBoost post-processing ---
# CatBoost Adjusted MAE: 6.3033

# %% [markdown]
# Looks like it was helpful to post process only for LightGBM and XGBoost.

# %% [markdown]
# ## Additional Feature Ideas Inspired by Kaggle Leaderboard
#
# We created additional features that we got the ideas from on the kaggle leaderboard.
#
# - `seconds_in_bucket_group`: Splits time into three groups: 0 (0-299 seconds), 1 (300-479 seconds), 2 (480+ seconds).
#
# - `bid_ask_spread`: Difference between ask (sell) and bid (buy) prices.
#
# - `imbalance_ratio`: Divides imbalance size (buy/sell order difference) by matched size (executed orders).
#
# - `mid_price`: Average of ask and bid prices.
#
# - `time_in_auction`: Normalizes time (seconds in bucket) by dividing by 540 to scale between 0 and 1.
#
# We also combined these with our original features into a combined function

# %%
# Written by Cooper and Attila 

# Helper functions
def _apply_non_leaderboard_features(data_df: pd.DataFrame) -> pd.DataFrame:
    # Volatility features
    data_df['wap_volatility'] = data_df.groupby('stock_id')['wap'].transform(
        lambda x: x.pct_change().rolling(window=5, min_periods=1).std()
    )
    data_df['bid_ask_spread'] = data_df['ask_price'] - data_df['bid_price']
    data_df['bid_ask_volatility'] = data_df.groupby('stock_id')['bid_ask_spread'].transform(
        lambda x: x.rolling(window=5, min_periods=1).std()
    )

    # Momentum features
    data_df['wap_momentum'] = data_df.groupby('stock_id')['wap'].transform(
        lambda x: x.pct_change(periods=3)
    )
    data_df['price_momentum'] = data_df.groupby('stock_id')['reference_price'].transform(
        lambda x: x.pct_change(periods=3)
    )

    # Log transformations
    size_cols = ['imbalance_size', 'matched_size', 'bid_size', 'ask_size']
    for col in size_cols:
        data_df[f'log_{col}'] = np.log1p(data_df[col].clip(lower=0))

    # Time-based interactions
    data_df['bucket_price_interaction'] = data_df['seconds_in_bucket'] * data_df['reference_price']
    data_df['bucket_imbalance_interaction'] = data_df['seconds_in_bucket'] * data_df['imbalance_size']

    # Relative price features
    data_df['wap_to_ref_price'] = data_df['wap'] / (data_df['reference_price'] + 1e-6)
    data_df['bid_to_ask_price'] = data_df['bid_price'] / (data_df['ask_price'] + 1e-6)

    # Handle NaN and inf for all newly created numerical columns
    # Exclude identifier/target columns as they are handled in the main processing functions
    new_cols_added = [col for col in data_df.columns if col not in ['stock_id', 'date_id', 'target', 'time_id', 'row_id']]
    # Filter to only numerical columns that might contain NaN/inf
    numerical_cols_to_fill = data_df[new_cols_added].select_dtypes(include=np.number).columns
    data_df[numerical_cols_to_fill] = data_df[numerical_cols_to_fill].replace([np.inf, -np.inf], np.nan)
    data_df[numerical_cols_to_fill] = data_df[numerical_cols_to_fill].fillna(data_df[numerical_cols_to_fill].median())

    return data_df

def _apply_leaderboard_features(data_df: pd.DataFrame) -> pd.DataFrame:
    # Handle NaN and infinities in specific input columns first as per original
    input_cols = ['imbalance_size', 'matched_size', 'ask_price', 'bid_price', 'wap', 'reference_price']
    for col in input_cols:
        data_df[col] = data_df[col].replace([np.inf, -np.inf], np.nan).fillna(data_df[col].median())

    # 1st Place: Seconds in bucket group
    data_df['seconds_in_bucket_group'] = np.where(data_df['seconds_in_bucket'] < 300, 0,
                                              np.where(data_df['seconds_in_bucket'] < 480, 1, 2))

    # 9th Place: Basic features
    data_df['bid_ask_spread'] = data_df['ask_price'] - data_df['bid_price']
    data_df['imbalance_ratio'] = data_df['imbalance_size'] / (data_df['matched_size'] + 1e-6)

    # 14th Place: Mid price
    data_df['mid_price'] = (data_df['ask_price'] + data_df['bid_price']) / 2

    # Time in auction
    data_df['time_in_auction'] = data_df['seconds_in_bucket'] / 540

    # Handle NaN and inf for newly created columns
    new_cols = ['seconds_in_bucket_group', 'bid_ask_spread', 'imbalance_ratio', 'mid_price', 'time_in_auction']
    data_df[new_cols] = data_df[new_cols].replace([np.inf, -np.inf], np.nan)
    data_df[new_cols] = data_df[new_cols].fillna(data_df[new_cols].median())

    return data_df


# Main data processing functions
def process_data_non_leaderboard(data: pd.DataFrame) -> tuple[pd.DataFrame, pd.Series]:
    df_copy = data.copy()
    # Drop rows where 'target' is null as these cannot be used for training
    df_copy.dropna(subset=["target"], inplace=True)
    df_processed = _apply_non_leaderboard_features(df_copy)

    X = df_processed.drop(["target", "time_id"], axis=1)
    y = df_processed["target"]
    return X, y

def process_data_leaderboard(data: pd.DataFrame) -> tuple[pd.DataFrame, pd.Series]:
    df_copy = data.copy()
    # Drop rows where 'target' is null as these cannot be used for training
    df_copy.dropna(subset=["target"], inplace=True)
    df_processed = _apply_leaderboard_features(df_copy)

    X = df_processed.drop(["target", "time_id"], axis=1)
    y = df_processed["target"]
    return X, y

def process_data_combined(data: pd.DataFrame) -> tuple[pd.DataFrame, pd.Series]:
    df_copy = data.copy()
    # Drop rows where 'target' is null as these cannot be used for training
    df_copy.dropna(subset=["target"], inplace=True)

    # Apply non-leaderboard features first
    df_processed = _apply_non_leaderboard_features(df_copy)

    # Apply additional combined features from the leaderboard approach
    # Handle NaN and infinities in specific input columns first as per original combined
    input_cols_combined = ['imbalance_size', 'matched_size', 'ask_price', 'bid_price', 'wap', 'reference_price']
    for col in input_cols_combined:
        df_processed[col] = df_processed[col].replace([np.inf, -np.inf], np.nan).fillna(df_processed[col].median())

    df_processed['seconds_in_bucket_group'] = np.where(df_processed['seconds_in_bucket'] < 300, 0,
                                              np.where(df_processed['seconds_in_bucket'] < 480, 1, 2))
    df_processed['imbalance_ratio'] = df_processed['imbalance_size'] / (df_processed['matched_size'] + 1e-6)
    df_processed['mid_price'] = (df_processed['ask_price'] + df_processed['bid_price']) / 2
    df_processed['time_in_auction'] = df_processed['seconds_in_bucket'] / 540

    # Handle NaN and inf for newly created combined features
    new_cols_combined = ['seconds_in_bucket_group', 'imbalance_ratio', 'mid_price', 'time_in_auction']
    df_processed[new_cols_combined] = df_processed[new_cols_combined].replace([np.inf, -np.inf], np.nan)
    df_processed[new_cols_combined] = df_processed[new_cols_combined].fillna(df_processed[new_cols_combined].median())

    X = df_processed.drop(["target", "time_id"], axis=1)
    y = df_processed["target"]
    return X, y

# %% [markdown]
# Now that these functions are defined we can evaluate our models on these features:

# %%
X, y = process_data_leaderboard(df.copy())
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=42)
mae_lgbm, lgbm_model = train_model(LGBMRegressor, X_train, y_train, X_val, y_val, params=lgbm_params)
mae_xgb, xgb_model = train_model(xgboost.XGBRegressor, X_train, y_train, X_val, y_val, params=xgb_params)
mae_cb, cb_model = train_model(CatBoostRegressor, X_train, y_train, X_val, y_val, params=cb_params)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003270 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3884
# [LightGBM] [Info] Number of data points in the train set: 350939, number of used features: 19
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Info] Start training from score -0.026625
# Training until validation scores don't improve for 150 rounds
# [150]	valid_0's l1: 6.30237
# [300]	valid_0's l1: 6.29669
# [450]	valid_0's l1: 6.29445
# [600]	valid_0's l1: 6.29393
# [750]	valid_0's l1: 6.29247
# [900]	valid_0's l1: 6.29081
# [1050]	valid_0's l1: 6.28935
# [1200]	valid_0's l1: 6.28805
# [1350]	valid_0's l1: 6.28789
# Early stopping, best iteration is:
# [1265]	valid_0's l1: 6.28771
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# /Users/bbwalrus/cfrm421-finalproj-1/.venv/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [02:07:48] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:203: XGBoost is not compiled with CUDA support.
#   bst.update(dtrain, iteration=i, fobj=obj)

# %% [markdown]
# This gets us the following results:

# %%
print(f"LightGBM MAE: {mae_lgbm:.4f}")
print(f"XGBoost MAE: {mae_xgb:.4f}")
print(f"CatBoost MAE: {mae_cb:.4f}")
# Out:
# LightGBM MAE: 6.2877
# XGBoost MAE: 6.2883
# CatBoost MAE: 6.2881

# %% [markdown]
# Now we can evaluate on combined features:

# %%
X, y = process_data_combined(df.copy())
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=42)
mae_lgbm, lgbm_model = train_model(LGBMRegressor, X_train, y_train, X_val, y_val, params=lgbm_params)
mae_xgb, xgb_model = train_model(xgboost.XGBRegressor, X_train, y_train, X_val, y_val, params=xgb_params)
mae_cb, cb_model = train_model(CatBoostRegressor, X_train, y_train, X_val, y_val, params=cb_params)
# Out:
# /var/folders/g0/hx8sq_xn5116f0v3hqmcb0lw0000gn/T/ipykernel_77279/2755009002.py:7: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   lambda x: x.pct_change().rolling(window=5, min_periods=1).std()
# /var/folders/g0/hx8sq_xn5116f0v3hqmcb0lw0000gn/T/ipykernel_77279/2755009002.py:16: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   lambda x: x.pct_change(periods=3)
# /var/folders/g0/hx8sq_xn5116f0v3hqmcb0lw0000gn/T/ipykernel_77279/2755009002.py:19: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   lambda x: x.pct_change(periods=3)
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005519 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6944
# [LightGBM] [Info] Number of data points in the train set: 350939, number of used features: 31
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [LightGBM] [Info] Start training from score -0.026625
# Training until validation scores don't improve for 150 rounds
# [150]	valid_0's l1: 6.29863
# [300]	valid_0's l1: 6.29358
# [450]	valid_0's l1: 6.29138
# [600]	valid_0's l1: 6.2911
# [750]	valid_0's l1: 6.28888
# [900]	valid_0's l1: 6.28726
# [1050]	valid_0's l1: 6.28689
# Early stopping, best iteration is:
# [1030]	valid_0's l1: 6.28671
# [LightGBM] [Warning] lambda_l1 is set=0.5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5
# [LightGBM] [Warning] lambda_l2 is set=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# /Users/bbwalrus/cfrm421-finalproj-1/.venv/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [02:09:24] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:203: XGBoost is not compiled with CUDA support.
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
print(f"LightGBM MAE: {mae_lgbm:.4f}")
print(f"XGBoost MAE: {mae_xgb:.4f}")
print(f"CatBoost MAE: {mae_cb:.4f}")
# Out:
# LightGBM MAE: 6.2867
# XGBoost MAE: 6.2874
# CatBoost MAE: 6.2806

# %% [markdown]
# # Results Analysis
#
# Our experiments have shown that the additional features definetely help improve the Mean Absolute Error of the models as features like seconds_in_bucket_group, imbalance_ratio, and mid_price help the models understand different auction phases, supply-demand imbalances, and price centrality which heavily impact how we model price movements.
#
# Despite having far fewer features and less development time than top leaderboard competitors as well as the top placers on the leaderboard being able to construct over 300 features for this dataset combined with the computing power to quickly test through those data sets, we were able to get relatively good enough results (the difference of MAE from number 1 to us is <1). This showcases the importance of selecting the right model combined with proper feature engineering. If we continued to develop more features and pick which subsets of features worked best we would be able to get good results. Unfortunately we were hit with a time limitation, as the Kaggle ran for over 6 months, while we only had realistically one week.

# %% [markdown]
# ## Areas of Improvement
#
# While our results with our current feature engineering and models have promising results, there a clear areas that we can optimize and refine upon to enhance performance.
#
# ### 1. Handling Missing Data
# We could improve upon how we handle the NaN rows of far_price and near_price. As a human, we know that this means that the orders did not fill for the auction, but the models have no way to tell. If we were to find some way to put this in a feature, it might improve the results of the model. Rather than simply dropping the values, creating an indicator to flag for missing migth help with providing better signals over masking patterns in the data.
#
# ### 2. Expanded feature Engineering
# Another area of improvement would be like previously mentioned, picking the best features and forgetting about other ones that worsen or elongate training time. The winning solution had hundreds of features, and going through each feature to determine the most important and relevant ones could increase accuracy.
#
# ### 3. Model Hyperparameter Tuning
# We could also try hyper parameter tuning the other models, as fine tuning hyperparameters such as learning rate, tree depth, number of estimators, regularization terms, and subsampling ratios can lead to significant gains.
#
# ### 4. Outside Kaggle Competition
# While in regards to the competition, we were supposed to only use the single dataset we were given if we were to continue to refine the model outside of it for real world applicatino, linking external data might help add additional context such as interest rates, CPI, or even news sentiment. Additionally, using other scoring methods such as time series cross validaiton could better reflect everchanging and sequential stock data.
#
# These would all be achievable given more time, and we would definitely see some improvement.
